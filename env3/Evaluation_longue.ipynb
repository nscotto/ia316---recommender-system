# %% [markdown]
# # Recommandation avec cold start

# %%
import pandas as pd

import seaborn as sns

from deep_implicit_feedback_recsys import *

from cold_star_recommender import *

from recommender_evaluation import *
# Out:
# Using TensorFlow backend.

# %%
def normalized_results(df, recommender_type):
    df['average_reward_normalized_max'] = df['average_reward'] / df['max_price']
    df['average_reward_normalized_mean'] = df['average_reward'] / df['mean_price']
    df['recommendation'] = recommender_type
    return df

# %%
n_loop = 10
n_pred = 1000
online_batch_size = n_pred // 10

user_dim = item_dim = 64
n_hidden = 1
hidden_size = 128
dropout = 0.1
l2_reg = 0

ID = 'MC15CHD1JU24INEKKPU4'

# %% [markdown]
# ## Mesures d'échantillon

# %% [markdown]
# ### Implicit Recommender avec nuls sans indicateur, en ligne

# %%
# %%time
ImplicitRecommenderWithNull_no_indicator_online_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull_no_indicator,
                                           n_loop=n_loop, n_pred=n_pred,
                                           online_batch_size=1,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg,
                                           ID=ID)
# Out:
# CPU times: user 1min 30s, sys: 2.41 s, total: 1min 32s
# Wall time: 3min 22s

# %%
ImplicitRecommenderWithNull_no_indicator_online_df_normalized = normalized_results(ImplicitRecommenderWithNull_no_indicator_online_df,
                                                                                   'Null, en ligne')
ImplicitRecommenderWithNull_no_indicator_online_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  978.352118   74.679091      280.479096            0.316
# 1  996.667890   80.795164      204.803295            0.243
# 2  994.063143   79.803732      237.878105            0.262
# 3  963.164055   67.485584      227.687375            0.265
# 4  880.329961   76.389319       43.692631            0.254
# 5  989.421048   61.726118       48.924152            0.252
# 6  832.375155   58.347470      233.368616            0.314
# 7  903.843153   57.838391      173.398807            0.218
# 8  965.397552   75.636393      315.420879            0.367
# 9  957.010197   74.185716       44.764948            0.257
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.286685                        3.755791
# 1                       0.205488                        2.534846
# 2                       0.239299                        2.980789
# 3                       0.236395                        3.373867
# 4                       0.049632                        0.571973
# 5                       0.049447                        0.792601
# 6                       0.280365                        3.999636
# 7                       0.191846                        2.997988
# 8                       0.326726                        4.170226
# 9                       0.046776                        0.603417
#
#    recommendation
# 0  Null, en ligne
# 1  Null, en ligne
# 2  Null, en ligne
# 3  Null, en ligne
# 4  Null, en ligne
# 5  Null, en ligne
# 6  Null, en ligne
# 7  Null, en ligne
# 8  Null, en ligne
# 9  Null, en ligne

# %% [markdown]
# ### Implicit Recommender avec nuls et indicateur special, hors ligne

# %%
# %%time
ImplicitRecommenderWithNull_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull,
                                           n_loop=n_loop, n_pred=n_pred,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg,
                                          ID=ID)
# Out:
# CPU times: user 1min 38s, sys: 2.42 s, total: 1min 40s
# Wall time: 2min 51s

# %%
ImplicitRecommenderWithNull_df_normalized = normalized_results(ImplicitRecommenderWithNull_df, 'Null special, hors ligne')
ImplicitRecommenderWithNull_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  990.257605   67.839567       54.143223            0.326
# 1  973.987908   73.625922      214.547942            0.240
# 2  943.138016   67.771638      265.712053            0.304
# 3  931.871287   62.300686      221.323848            0.264
# 4  994.632948   74.995065       51.129533            0.257
# 5  956.323552   62.658884      215.258131            0.247
# 6  940.097942   75.799336      282.577884            0.366
# 7  914.222766   72.999897       37.322377            0.266
# 8  813.956344   67.878820       32.218503            0.254
# 9  974.515894   68.454243       38.243483            0.236
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.054676                        0.798107
# 1                       0.220278                        2.914027
# 2                       0.281732                        3.920697
# 3                       0.237505                        3.552511
# 4                       0.051405                        0.681772
# 5                       0.225089                        3.435397
# 6                       0.300583                        3.727973
# 7                       0.040824                        0.511266
# 8                       0.039583                        0.474647
# 9                       0.039244                        0.558672
#
#              recommendation
# 0  Null special, hors ligne
# 1  Null special, hors ligne
# 2  Null special, hors ligne
# 3  Null special, hors ligne
# 4  Null special, hors ligne
# 5  Null special, hors ligne
# 6  Null special, hors ligne
# 7  Null special, hors ligne
# 8  Null special, hors ligne
# 9  Null special, hors ligne

# %% [markdown]
# ### Implicit Recommender avec nuls et indicateur special, en ligne

# %%
# %%time
ImplicitRecommenderWithNull_online_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull,
                                           n_loop=n_loop, n_pred=n_pred,
                                           online_batch_size=1,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg,
                                          ID=ID)
# Out:
# CPU times: user 1min 52s, sys: 2.81 s, total: 1min 55s
# Wall time: 3min 35s

# %%
ImplicitRecommenderWithNull_online_df_normalized = normalized_results(ImplicitRecommenderWithNull_online_df, 'Null special, en ligne')
ImplicitRecommenderWithNull_online_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  978.188779   75.784563      308.517970            0.344
# 1  991.330012   68.260146      249.700093            0.280
# 2  955.714789   70.255655      102.562568            0.383
# 3  994.068440   89.415887      269.233355            0.295
# 4  942.082170   63.121125      242.411940            0.296
# 5  960.998669   79.957158       95.698034            0.364
# 6  966.136239   64.855745      184.098408            0.213
# 7  809.433013   62.953491      164.156538            0.247
# 8  995.371066   71.959412       38.237598            0.235
# 9  986.164629   66.803295      291.189702            0.322
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.315397                        4.070987
# 1                       0.251884                        3.658066
# 2                       0.107315                        1.459848
# 3                       0.270840                        3.011024
# 4                       0.257315                        3.840425
# 5                       0.099582                        1.196866
# 6                       0.190551                        2.838583
# 7                       0.202804                        2.607584
# 8                       0.038415                        0.531377
# 9                       0.295275                        4.358912
#
#            recommendation
# 0  Null special, en ligne
# 1  Null special, en ligne
# 2  Null special, en ligne
# 3  Null special, en ligne
# 4  Null special, en ligne
# 5  Null special, en ligne
# 6  Null special, en ligne
# 7  Null special, en ligne
# 8  Null special, en ligne
# 9  Null special, en ligne

# %% [markdown]
# ### Implicit Recommender avec nuls et indicateur special, en ligne version batch

# %%
# %%time
ImplicitRecommenderWithNull_online_batch_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull,
                                           n_loop=n_loop, n_pred=n_pred,
                                           online_batch_size=online_batch_size,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg,
                                          ID=ID)
# Out:
# CPU times: user 1min 55s, sys: 2.56 s, total: 1min 58s
# Wall time: 3min 17s

# %%
ImplicitRecommenderWithNull_online_batch_df_normalized = \
    normalized_results(ImplicitRecommenderWithNull_online_batch_df, 'Null special, en ligne (batch)')
ImplicitRecommenderWithNull_online_batch_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  916.678669   77.553185       39.738984            0.267
# 1  976.946667   69.983581      247.066321            0.289
# 2  883.804623   56.562206       38.866177            0.179
# 3  995.878401   87.007940       60.596966            0.285
# 4  973.256440   67.855009      259.789630            0.296
# 5  998.341435   71.698402      212.225152            0.247
# 6  989.898985   82.506246      222.260146            0.248
# 7  982.872128   70.711216       53.108947            0.310
# 8  987.762863   72.475865      255.244547            0.287
# 9  946.884960   61.423174      262.844543            0.298
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.043351                        0.512409
# 1                       0.252896                        3.530347
# 2                       0.043976                        0.687140
# 3                       0.060848                        0.696453
# 4                       0.266928                        3.828599
# 5                       0.212578                        2.959970
# 6                       0.224528                        2.693858
# 7                       0.054034                        0.751068
# 8                       0.258407                        3.521787
# 9                       0.277589                        4.279241
#
#                    recommendation
# 0  Null special, en ligne (batch)
# 1  Null special, en ligne (batch)
# 2  Null special, en ligne (batch)
# 3  Null special, en ligne (batch)
# 4  Null special, en ligne (batch)
# 5  Null special, en ligne (batch)
# 6  Null special, en ligne (batch)
# 7  Null special, en ligne (batch)
# 8  Null special, en ligne (batch)
# 9  Null special, en ligne (batch)

# %% [markdown]
# ### Fully Implicit Recommender avec nuls et indicateur binaire, en ligne version batch

# %%
# %%time
FullyImplicitRecommenderWithNull_binary_indicator_online_batch_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartFullyImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull_binary_indicator,
                                           n_loop=n_loop, n_pred=n_pred,
                                           online_batch_size=online_batch_size,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg,
                                          ID=ID)
# Out:
# CPU times: user 1min 11s, sys: 1.28 s, total: 1min 12s
# Wall time: 2min 48s

# %%
FullyImplicitRecommenderWithNull_binary_indicator_online_batch_df_normalized = \
    normalized_results(FullyImplicitRecommenderWithNull_binary_indicator_online_batch_df, 'Fully Implicit Null binaire, en ligne (batch)')
FullyImplicitRecommenderWithNull_binary_indicator_online_batch_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  962.897075   66.894059      166.412824            0.305
# 1  828.295135   84.425122      190.706478            0.292
# 2  954.655066   73.513830      193.367120            0.277
# 3  992.624480   60.709578      157.259325            0.288
# 4  974.654114   70.049043      158.384092            0.274
# 5  928.103797   72.229078      146.653930            0.262
# 6  953.951121   63.661072      158.734552            0.319
# 7  998.969659   80.982220      251.995188            0.340
# 8  965.932043   78.981864      195.223253            0.306
# 9  900.444802   75.880168      168.533559            0.308
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.172825                        2.487707
# 1                       0.230240                        2.258883
# 2                       0.202552                        2.630350
# 3                       0.158428                        2.590354
# 4                       0.162503                        2.261046
# 5                       0.158015                        2.030400
# 6                       0.166397                        2.493432
# 7                       0.252255                        3.111735
# 8                       0.202109                        2.471748
# 9                       0.187167                        2.221049
#
#                                   recommendation
# 0  Fully Implicit Null binaire, en ligne (batch)
# 1  Fully Implicit Null binaire, en ligne (batch)
# 2  Fully Implicit Null binaire, en ligne (batch)
# 3  Fully Implicit Null binaire, en ligne (batch)
# 4  Fully Implicit Null binaire, en ligne (batch)
# 5  Fully Implicit Null binaire, en ligne (batch)
# 6  Fully Implicit Null binaire, en ligne (batch)
# 7  Fully Implicit Null binaire, en ligne (batch)
# 8  Fully Implicit Null binaire, en ligne (batch)
# 9  Fully Implicit Null binaire, en ligne (batch)

# %% [markdown]
# ## Aggregation des résutats

# %%
all_results = pd.concat( (
    ImplicitRecommenderWithNull_no_indicator_online_df_normalized,
    ImplicitRecommenderWithNull_df_normalized,
    ImplicitRecommenderWithNull_online_df_normalized,
    ImplicitRecommenderWithNull_online_batch_df_normalized,
    
    FullyImplicitRecommenderWithNull_binary_indicator_online_batch_df_normalized,
), axis = 0)

# %%
aggregat = all_results.groupby('recommendation').mean()

# %% [markdown]
# ### Classement ratio de recommandations effectives

# %%
col = 'good_reco_ratio' 
aggregat.sort_values(col, ascending=False)\
    .style.apply((lambda x: ['background: lightgreen' if x.name == col else '' for _ in x]))
# Out:
# <style  type="text/css" >
#     #T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row0_col3 {
#             background:  lightgreen;
#         }    #T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row1_col3 {
#             background:  lightgreen;
#         }    #T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row2_col3 {
#             background:  lightgreen;
#         }    #T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row3_col3 {
#             background:  lightgreen;
#         }    #T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row4_col3 {
#             background:  lightgreen;
#         }</style><table id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >max_price</th>        <th class="col_heading level0 col1" >mean_price</th>        <th class="col_heading level0 col2" >average_reward</th>        <th class="col_heading level0 col3" >good_reco_ratio</th>        <th class="col_heading level0 col4" >average_reward_normalized_max</th>        <th class="col_heading level0 col5" >average_reward_normalized_mean</th>    </tr>    <tr>        <th class="index_name level0" >recommendation</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236level0_row0" class="row_heading level0 row0" >Null special, en ligne</th>
#                         <td id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row0_col0" class="data row0 col0" >957.949</td>
#                         <td id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row0_col1" class="data row0 col1" >71.3366</td>
#                         <td id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row0_col2" class="data row0 col2" >194.581</td>
#                         <td id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row0_col3" class="data row0 col3" >0.2979</td>
#                         <td id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row0_col4" class="data row0 col4" >0.202938</td>
#                         <td id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row0_col5" class="data row0 col5" >2.75737</td>
#             </tr>
#             <tr>
#                         <th id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236level0_row1" class="row_heading level0 row1" >Fully Implicit Null binaire, en ligne (batch)</th>
#                         <td id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row1_col0" class="data row1 col0" >946.053</td>
#                         <td id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row1_col1" class="data row1 col1" >72.7326</td>
#                         <td id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row1_col2" class="data row1 col2" >178.727</td>
#                         <td id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row1_col3" class="data row1 col3" >0.2971</td>
#                         <td id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row1_col4" class="data row1 col4" >0.189249</td>
#                         <td id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row1_col5" class="data row1 col5" >2.45567</td>
#             </tr>
#             <tr>
#                         <th id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236level0_row2" class="row_heading level0 row2" >Null special, hors ligne</th>
#                         <td id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row2_col0" class="data row2 col0" >943.3</td>
#                         <td id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row2_col1" class="data row2 col1" >69.4324</td>
#                         <td id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row2_col2" class="data row2 col2" >141.248</td>
#                         <td id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row2_col3" class="data row2 col3" >0.276</td>
#                         <td id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row2_col4" class="data row2 col4" >0.149092</td>
#                         <td id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row2_col5" class="data row2 col5" >2.05751</td>
#             </tr>
#             <tr>
#                         <th id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236level0_row3" class="row_heading level0 row3" >Null, en ligne</th>
#                         <td id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row3_col0" class="data row3 col0" >946.062</td>
#                         <td id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row3_col1" class="data row3 col1" >70.6887</td>
#                         <td id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row3_col2" class="data row3 col2" >181.042</td>
#                         <td id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row3_col3" class="data row3 col3" >0.2748</td>
#                         <td id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row3_col4" class="data row3 col4" >0.191266</td>
#                         <td id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row3_col5" class="data row3 col5" >2.57811</td>
#             </tr>
#             <tr>
#                         <th id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236level0_row4" class="row_heading level0 row4" >Null special, en ligne (batch)</th>
#                         <td id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row4_col0" class="data row4 col0" >965.233</td>
#                         <td id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row4_col1" class="data row4 col1" >71.7777</td>
#                         <td id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row4_col2" class="data row4 col2" >165.174</td>
#                         <td id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row4_col3" class="data row4 col3" >0.2706</td>
#                         <td id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row4_col4" class="data row4 col4" >0.169514</td>
#                         <td id="T_9e0f792c_3b4f_11e9_8da5_79fa30dc3236row4_col5" class="data row4 col5" >2.34609</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Classement par average reward normalisée (max)

# %%
col = 'average_reward_normalized_max' 
aggregat.sort_values(col, ascending=False)\
    .style.apply((lambda x: ['background: lightgreen' if x.name == col else '' for _ in x]))
# Out:
# <style  type="text/css" >
#     #T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row0_col4 {
#             background:  lightgreen;
#         }    #T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row1_col4 {
#             background:  lightgreen;
#         }    #T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row2_col4 {
#             background:  lightgreen;
#         }    #T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row3_col4 {
#             background:  lightgreen;
#         }    #T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row4_col4 {
#             background:  lightgreen;
#         }</style><table id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >max_price</th>        <th class="col_heading level0 col1" >mean_price</th>        <th class="col_heading level0 col2" >average_reward</th>        <th class="col_heading level0 col3" >good_reco_ratio</th>        <th class="col_heading level0 col4" >average_reward_normalized_max</th>        <th class="col_heading level0 col5" >average_reward_normalized_mean</th>    </tr>    <tr>        <th class="index_name level0" >recommendation</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236level0_row0" class="row_heading level0 row0" >Null special, en ligne</th>
#                         <td id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row0_col0" class="data row0 col0" >957.949</td>
#                         <td id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row0_col1" class="data row0 col1" >71.3366</td>
#                         <td id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row0_col2" class="data row0 col2" >194.581</td>
#                         <td id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row0_col3" class="data row0 col3" >0.2979</td>
#                         <td id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row0_col4" class="data row0 col4" >0.202938</td>
#                         <td id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row0_col5" class="data row0 col5" >2.75737</td>
#             </tr>
#             <tr>
#                         <th id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236level0_row1" class="row_heading level0 row1" >Null, en ligne</th>
#                         <td id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row1_col0" class="data row1 col0" >946.062</td>
#                         <td id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row1_col1" class="data row1 col1" >70.6887</td>
#                         <td id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row1_col2" class="data row1 col2" >181.042</td>
#                         <td id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row1_col3" class="data row1 col3" >0.2748</td>
#                         <td id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row1_col4" class="data row1 col4" >0.191266</td>
#                         <td id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row1_col5" class="data row1 col5" >2.57811</td>
#             </tr>
#             <tr>
#                         <th id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236level0_row2" class="row_heading level0 row2" >Fully Implicit Null binaire, en ligne (batch)</th>
#                         <td id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row2_col0" class="data row2 col0" >946.053</td>
#                         <td id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row2_col1" class="data row2 col1" >72.7326</td>
#                         <td id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row2_col2" class="data row2 col2" >178.727</td>
#                         <td id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row2_col3" class="data row2 col3" >0.2971</td>
#                         <td id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row2_col4" class="data row2 col4" >0.189249</td>
#                         <td id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row2_col5" class="data row2 col5" >2.45567</td>
#             </tr>
#             <tr>
#                         <th id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236level0_row3" class="row_heading level0 row3" >Null special, en ligne (batch)</th>
#                         <td id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row3_col0" class="data row3 col0" >965.233</td>
#                         <td id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row3_col1" class="data row3 col1" >71.7777</td>
#                         <td id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row3_col2" class="data row3 col2" >165.174</td>
#                         <td id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row3_col3" class="data row3 col3" >0.2706</td>
#                         <td id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row3_col4" class="data row3 col4" >0.169514</td>
#                         <td id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row3_col5" class="data row3 col5" >2.34609</td>
#             </tr>
#             <tr>
#                         <th id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236level0_row4" class="row_heading level0 row4" >Null special, hors ligne</th>
#                         <td id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row4_col0" class="data row4 col0" >943.3</td>
#                         <td id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row4_col1" class="data row4 col1" >69.4324</td>
#                         <td id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row4_col2" class="data row4 col2" >141.248</td>
#                         <td id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row4_col3" class="data row4 col3" >0.276</td>
#                         <td id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row4_col4" class="data row4 col4" >0.149092</td>
#                         <td id="T_9e124d82_3b4f_11e9_8da5_79fa30dc3236row4_col5" class="data row4 col5" >2.05751</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Classement par average reward normalisée (mean)

# %%
col = 'average_reward_normalized_mean' 
aggregat.sort_values(col, ascending=False)\
    .style.apply((lambda x: ['background: lightgreen' if x.name == col else '' for _ in x]))
# Out:
# <style  type="text/css" >
#     #T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row0_col5 {
#             background:  lightgreen;
#         }    #T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row1_col5 {
#             background:  lightgreen;
#         }    #T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row2_col5 {
#             background:  lightgreen;
#         }    #T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row3_col5 {
#             background:  lightgreen;
#         }    #T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row4_col5 {
#             background:  lightgreen;
#         }</style><table id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >max_price</th>        <th class="col_heading level0 col1" >mean_price</th>        <th class="col_heading level0 col2" >average_reward</th>        <th class="col_heading level0 col3" >good_reco_ratio</th>        <th class="col_heading level0 col4" >average_reward_normalized_max</th>        <th class="col_heading level0 col5" >average_reward_normalized_mean</th>    </tr>    <tr>        <th class="index_name level0" >recommendation</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236level0_row0" class="row_heading level0 row0" >Null special, en ligne</th>
#                         <td id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row0_col0" class="data row0 col0" >957.949</td>
#                         <td id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row0_col1" class="data row0 col1" >71.3366</td>
#                         <td id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row0_col2" class="data row0 col2" >194.581</td>
#                         <td id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row0_col3" class="data row0 col3" >0.2979</td>
#                         <td id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row0_col4" class="data row0 col4" >0.202938</td>
#                         <td id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row0_col5" class="data row0 col5" >2.75737</td>
#             </tr>
#             <tr>
#                         <th id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236level0_row1" class="row_heading level0 row1" >Null, en ligne</th>
#                         <td id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row1_col0" class="data row1 col0" >946.062</td>
#                         <td id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row1_col1" class="data row1 col1" >70.6887</td>
#                         <td id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row1_col2" class="data row1 col2" >181.042</td>
#                         <td id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row1_col3" class="data row1 col3" >0.2748</td>
#                         <td id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row1_col4" class="data row1 col4" >0.191266</td>
#                         <td id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row1_col5" class="data row1 col5" >2.57811</td>
#             </tr>
#             <tr>
#                         <th id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236level0_row2" class="row_heading level0 row2" >Fully Implicit Null binaire, en ligne (batch)</th>
#                         <td id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row2_col0" class="data row2 col0" >946.053</td>
#                         <td id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row2_col1" class="data row2 col1" >72.7326</td>
#                         <td id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row2_col2" class="data row2 col2" >178.727</td>
#                         <td id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row2_col3" class="data row2 col3" >0.2971</td>
#                         <td id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row2_col4" class="data row2 col4" >0.189249</td>
#                         <td id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row2_col5" class="data row2 col5" >2.45567</td>
#             </tr>
#             <tr>
#                         <th id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236level0_row3" class="row_heading level0 row3" >Null special, en ligne (batch)</th>
#                         <td id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row3_col0" class="data row3 col0" >965.233</td>
#                         <td id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row3_col1" class="data row3 col1" >71.7777</td>
#                         <td id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row3_col2" class="data row3 col2" >165.174</td>
#                         <td id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row3_col3" class="data row3 col3" >0.2706</td>
#                         <td id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row3_col4" class="data row3 col4" >0.169514</td>
#                         <td id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row3_col5" class="data row3 col5" >2.34609</td>
#             </tr>
#             <tr>
#                         <th id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236level0_row4" class="row_heading level0 row4" >Null special, hors ligne</th>
#                         <td id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row4_col0" class="data row4 col0" >943.3</td>
#                         <td id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row4_col1" class="data row4 col1" >69.4324</td>
#                         <td id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row4_col2" class="data row4 col2" >141.248</td>
#                         <td id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row4_col3" class="data row4 col3" >0.276</td>
#                         <td id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row4_col4" class="data row4 col4" >0.149092</td>
#                         <td id="T_9e14fab4_3b4f_11e9_8da5_79fa30dc3236row4_col5" class="data row4 col5" >2.05751</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Résumé (classé par average_reward)

# %%
cm = sns.light_palette("green", as_cmap=True)
col = ['average_reward_normalized_max', 'average_reward_normalized_mean']
aggregat.sort_values(col, ascending=False)\
    .style.background_gradient(cmap=cm).highlight_max(color='red')
# Out:
# <style  type="text/css" >
#     #T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row0_col0 {
#             background-color:  #4daa4d;
#             color:  #000000;
#             : ;
#         }    #T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row0_col1 {
#             background-color:  #61b661;
#             color:  #000000;
#             : ;
#         }    #T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row0_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             background-color:  red;
#         }    #T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row0_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             background-color:  red;
#         }    #T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row0_col4 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             background-color:  red;
#         }    #T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row0_col5 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             background-color:  red;
#         }    #T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row1_col0 {
#             background-color:  #c9efc9;
#             color:  #000000;
#             : ;
#         }    #T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row1_col1 {
#             background-color:  #8ecf8e;
#             color:  #000000;
#             : ;
#         }    #T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row1_col2 {
#             background-color:  #3aa03a;
#             color:  #000000;
#             : ;
#         }    #T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row1_col3 {
#             background-color:  #c2ecc2;
#             color:  #000000;
#             : ;
#         }    #T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row1_col4 {
#             background-color:  #319b31;
#             color:  #000000;
#             : ;
#         }    #T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row1_col5 {
#             background-color:  #3aa03a;
#             color:  #000000;
#             : ;
#         }    #T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row2_col0 {
#             background-color:  #c9efc9;
#             color:  #000000;
#             : ;
#         }    #T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row2_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             background-color:  red;
#         }    #T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row2_col2 {
#             background-color:  #44a644;
#             color:  #000000;
#             : ;
#         }    #T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row2_col3 {
#             background-color:  #068306;
#             color:  #f1f1f1;
#             : ;
#         }    #T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row2_col4 {
#             background-color:  #3aa03a;
#             color:  #000000;
#             : ;
#         }    #T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row2_col5 {
#             background-color:  #63b763;
#             color:  #000000;
#             : ;
#         }    #T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row3_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             background-color:  red;
#         }    #T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row3_col1 {
#             background-color:  #43a543;
#             color:  #000000;
#             : ;
#         }    #T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row3_col2 {
#             background-color:  #7fc67f;
#             color:  #000000;
#             : ;
#         }    #T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row3_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row3_col4 {
#             background-color:  #8ecf8e;
#             color:  #000000;
#             : ;
#         }    #T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row3_col5 {
#             background-color:  #87cb87;
#             color:  #000000;
#             : ;
#         }    #T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row4_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row4_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row4_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row4_col3 {
#             background-color:  #b8e6b8;
#             color:  #000000;
#             : ;
#         }    #T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row4_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row4_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }</style><table id="T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >max_price</th>        <th class="col_heading level0 col1" >mean_price</th>        <th class="col_heading level0 col2" >average_reward</th>        <th class="col_heading level0 col3" >good_reco_ratio</th>        <th class="col_heading level0 col4" >average_reward_normalized_max</th>        <th class="col_heading level0 col5" >average_reward_normalized_mean</th>    </tr>    <tr>        <th class="index_name level0" >recommendation</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236level0_row0" class="row_heading level0 row0" >Null special, en ligne</th>
#                         <td id="T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row0_col0" class="data row0 col0" >957.949</td>
#                         <td id="T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row0_col1" class="data row0 col1" >71.3366</td>
#                         <td id="T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row0_col2" class="data row0 col2" >194.581</td>
#                         <td id="T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row0_col3" class="data row0 col3" >0.2979</td>
#                         <td id="T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row0_col4" class="data row0 col4" >0.202938</td>
#                         <td id="T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row0_col5" class="data row0 col5" >2.75737</td>
#             </tr>
#             <tr>
#                         <th id="T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236level0_row1" class="row_heading level0 row1" >Null, en ligne</th>
#                         <td id="T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row1_col0" class="data row1 col0" >946.062</td>
#                         <td id="T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row1_col1" class="data row1 col1" >70.6887</td>
#                         <td id="T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row1_col2" class="data row1 col2" >181.042</td>
#                         <td id="T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row1_col3" class="data row1 col3" >0.2748</td>
#                         <td id="T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row1_col4" class="data row1 col4" >0.191266</td>
#                         <td id="T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row1_col5" class="data row1 col5" >2.57811</td>
#             </tr>
#             <tr>
#                         <th id="T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236level0_row2" class="row_heading level0 row2" >Fully Implicit Null binaire, en ligne (batch)</th>
#                         <td id="T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row2_col0" class="data row2 col0" >946.053</td>
#                         <td id="T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row2_col1" class="data row2 col1" >72.7326</td>
#                         <td id="T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row2_col2" class="data row2 col2" >178.727</td>
#                         <td id="T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row2_col3" class="data row2 col3" >0.2971</td>
#                         <td id="T_9e1ad72c_3b4f_11e9_8da5_79fa30dc3236row2_col4" class="data row2 col4" >0.189249</td>
#                         <td

# %% [markdown]
# La recommendation prenant en charge les nulls semble meilleure. <br>
#   1) Null secial en ligne<br>
#   2) Null en ligne<br>
#   3) Fully Implicit Null binaire, en ligne (batch)<br>

# %% [markdown]
# Précédemment : <br>
# La recommendation prenant en charge les nulls semble meilleure. <br>
#   1) Null secial en ligne (batch) <br>
#   2) Fully Implicit Null special, en ligne (batch) <br>
#   3) Null, hors ligne <br>
