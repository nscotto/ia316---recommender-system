# %% [markdown]
# # Recommandation avec cold start

# %%
import pandas as pd

import seaborn as sns

from deep_implicit_feedback_recsys import *

from cold_star_recommender import *

from recommender_evaluation import *

# %%
def normalized_results(df, recommender_type):
    df['average_reward_normalized_max'] = df['average_reward'] / df['max_price']
    df['average_reward_normalized_mean'] = df['average_reward'] / df['mean_price']
    df['recommendation'] = recommender_type
    return df

# %%
n_loop = 10
n_pred = 100
online_batch_size = n_pred // 10

user_dim = item_dim = 8
n_hidden = 1
hidden_size = 64
dropout = 0.1
l2_reg = 0

# %% [markdown]
# ## Mesures d'échantillon

# %% [markdown]
# ### Implicit Recommender Simple, hors ligne

# %%
# %%time
ImplicitRecommenderSimple_df = eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartImplicitRecommender,
                                                                      ImplicitRecommenderClass=ImplicitRecommenderSimple, 
                                                                      n_loop=n_loop, n_pred=n_pred,
                                                                      user_dim=user_dim, item_dim=item_dim,
                                                                      n_hidden=n_hidden, hidden_size=hidden_size, 
                                                                      dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 28.4 s, sys: 442 ms, total: 28.9 s
# Wall time: 40.5 s

# %%
ImplicitRecommenderSimple_df_normalized = normalized_results(ImplicitRecommenderSimple_df, 'Simple, hors ligne')
ImplicitRecommenderSimple_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  959.737052   73.746539       61.596141             0.32
# 1  996.846187   70.448032      105.031519             0.35
# 2  983.485803   78.028259      135.889914             0.33
# 3  980.204459   68.611955       78.895781             0.28
# 4  987.541172   67.009611       95.596585             0.36
# 5  939.570760   82.625846       97.368155             0.33
# 6  983.476780   68.696256       85.038388             0.27
# 7  979.671907   63.944929      127.366202             0.38
# 8  992.369747   77.885127      120.222295             0.46
# 9  982.953384   86.216667       48.279875             0.25
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.064180                        0.835241
# 1                       0.105364                        1.490908
# 2                       0.138172                        1.741547
# 3                       0.080489                        1.149884
# 4                       0.096803                        1.426610
# 5                       0.103630                        1.178422
# 6                       0.086467                        1.237890
# 7                       0.130009                        1.991811
# 8                       0.121147                        1.543585
# 9                       0.049117                        0.559983
#
#        recommendation
# 0  Simple, hors ligne
# 1  Simple, hors ligne
# 2  Simple, hors ligne
# 3  Simple, hors ligne
# 4  Simple, hors ligne
# 5  Simple, hors ligne
# 6  Simple, hors ligne
# 7  Simple, hors ligne
# 8  Simple, hors ligne
# 9  Simple, hors ligne

# %% [markdown]
# ### Implicit Recommender Simple, en ligne

# %%
# %%time
ImplicitRecommenderSimple_online_df = eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartImplicitRecommender,
                                                                             ImplicitRecommenderClass=ImplicitRecommenderSimple,
                                                                             n_loop=n_loop, n_pred=n_pred,
                                                                             online_batch_size=1,
                                                                             user_dim=user_dim, item_dim=item_dim,
                                                                             n_hidden=n_hidden, hidden_size=hidden_size, 
                                                                             dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 34.1 s, sys: 494 ms, total: 34.6 s
# Wall time: 54.5 s

# %%
ImplicitRecommenderSimple_online_df_normalized = normalized_results(ImplicitRecommenderSimple_online_df, 'Simple, en ligne')
ImplicitRecommenderSimple_online_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  972.848692   68.776290       99.423666             0.30
# 1  945.077172   55.303744      261.602161             0.40
# 2  916.910786   65.853997      242.704934             0.31
# 3  992.426178   80.158920      254.363224             0.33
# 4  977.096174   78.014046       78.038736             0.18
# 5  996.571870   72.684800      120.971361             0.37
# 6  886.562526   72.167547      236.517135             0.31
# 7  944.297361   57.890893       86.293806             0.44
# 8  923.621669   65.775868      254.236294             0.37
# 9  943.022143   58.965789      161.165768             0.22
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.102198                        1.445610
# 1                       0.276805                        4.730279
# 2                       0.264699                        3.685500
# 3                       0.256304                        3.173237
# 4                       0.079868                        1.000316
# 5                       0.121387                        1.664328
# 6                       0.266780                        3.277334
# 7                       0.091384                        1.490628
# 8                       0.275260                        3.865191
# 9                       0.170903                        2.733208
#
#      recommendation
# 0  Simple, en ligne
# 1  Simple, en ligne
# 2  Simple, en ligne
# 3  Simple, en ligne
# 4  Simple, en ligne
# 5  Simple, en ligne
# 6  Simple, en ligne
# 7  Simple, en ligne
# 8  Simple, en ligne
# 9  Simple, en ligne

# %% [markdown]
# ### Implicit Recommender Simple, en ligne version batch

# %%
# %%time
ImplicitRecommenderSimple_online_batch_df = eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartImplicitRecommender,
                                                                             ImplicitRecommenderClass=ImplicitRecommenderSimple,
                                                                             n_loop=n_loop, n_pred=n_pred,
                                                                             user_dim=user_dim, item_dim=item_dim,
                                                                             online_batch_size=online_batch_size,
                                                                             n_hidden=n_hidden, hidden_size=hidden_size, 
                                                                             dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 39.5 s, sys: 521 ms, total: 40 s
# Wall time: 54.3 s

# %%
ImplicitRecommenderSimple_online_batch_df_normalized = normalized_results(ImplicitRecommenderSimple_online_batch_df, 'Simple, en ligne (batch)')
ImplicitRecommenderSimple_online_batch_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  993.930552   61.756401       92.358685             0.33
# 1  937.388470   66.014776       91.330081             0.28
# 2  941.895181   74.351325       82.921620             0.32
# 3  978.412197   80.648464      103.851215             0.39
# 4  977.236264   71.345237      229.321811             0.28
# 5  969.230251   55.214068      199.310121             0.26
# 6  988.780844   83.837401       86.132071             0.33
# 7  961.347955   58.628357      107.214414             0.34
# 8  958.688261   74.172479      361.656084             0.44
# 9  988.017145   92.644722      197.550487             0.25
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.092923                        1.495532
# 1                       0.097430                        1.383479
# 2                       0.088037                        1.115268
# 3                       0.106143                        1.287702
# 4                       0.234664                        3.214255
# 5                       0.205638                        3.609771
# 6                       0.087109                        1.027370
# 7                       0.111525                        1.828713
# 8                       0.377241                        4.875880
# 9                       0.199946                        2.132345
#
#              recommendation
# 0  Simple, en ligne (batch)
# 1  Simple, en ligne (batch)
# 2  Simple, en ligne (batch)
# 3  Simple, en ligne (batch)
# 4  Simple, en ligne (batch)
# 5  Simple, en ligne (batch)
# 6  Simple, en ligne (batch)
# 7  Simple, en ligne (batch)
# 8  Simple, en ligne (batch)
# 9  Simple, en ligne (batch)

# %% [markdown]
# ### Implicit Recommender avec nuls sans indicateur, hors ligne

# %%
# %%time
ImplicitRecommenderWithNull_no_indicator_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull_no_indicator, 
                                           n_loop=n_loop, n_pred=n_pred,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 47.4 s, sys: 660 ms, total: 48.1 s
# Wall time: 56.9 s

# %%
ImplicitRecommenderWithNull_no_indicator_df_normalized = normalized_results(ImplicitRecommenderWithNull_no_indicator_df, 'Null, hors ligne')
ImplicitRecommenderWithNull_no_indicator_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  906.892092   76.118942       85.102518             0.30
# 1  995.424876   66.010686      139.754115             0.30
# 2  972.839505   71.598976      264.218849             0.32
# 3  957.594350   73.054839      248.845306             0.32
# 4  943.452975   63.266867      181.887980             0.26
# 5  965.598134   67.901070      317.636490             0.36
# 6  990.806311   68.589820      224.031767             0.28
# 7  995.363368   59.269212      287.001618             0.40
# 8  993.323094   70.840044      106.775370             0.30
# 9  976.742046   60.449901       58.608571             0.31
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.093840                        1.118020
# 1                       0.140396                        2.117144
# 2                       0.271596                        3.690260
# 3                       0.259865                        3.406281
# 4                       0.192790                        2.874933
# 5                       0.328953                        4.677931
# 6                       0.226111                        3.266254
# 7                       0.288339                        4.842339
# 8                       0.107493                        1.507274
# 9                       0.060004                        0.969540
#
#      recommendation
# 0  Null, hors ligne
# 1  Null, hors ligne
# 2  Null, hors ligne
# 3  Null, hors ligne
# 4  Null, hors ligne
# 5  Null, hors ligne
# 6  Null, hors ligne
# 7  Null, hors ligne
# 8  Null, hors ligne
# 9  Null, hors ligne

# %% [markdown]
# ### Implicit Recommender avec nuls sans indicateur, en ligne

# %%
# %%time
ImplicitRecommenderWithNull_no_indicator_online_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull_no_indicator,
                                           n_loop=n_loop, n_pred=n_pred,
                                           online_batch_size=1,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 53.5 s, sys: 692 ms, total: 54.2 s
# Wall time: 1min 3s

# %%
ImplicitRecommenderWithNull_no_indicator_online_df_normalized = normalized_results(ImplicitRecommenderWithNull_no_indicator_online_df,
                                                                                   'Null, en ligne')
ImplicitRecommenderWithNull_no_indicator_online_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  952.262807   75.734863      247.314599             0.33
# 1  917.676865   57.296364      145.950877             0.41
# 2  912.079811   64.798087      110.201170             0.24
# 3  963.113279   61.451105      180.049601             0.26
# 4  992.480323   78.690023      112.429248             0.31
# 5  984.356955   73.534389      183.582122             0.31
# 6  966.007373   83.860387      377.387794             0.46
# 7  977.222426   65.867878      228.079800             0.32
# 8  908.430041   69.939080      119.407841             0.41
# 9  949.650683   68.143028      251.034169             0.33
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.259713                        3.265532
# 1                       0.159044                        2.547297
# 2                       0.120824                        1.700686
# 3                       0.186945                        2.929965
# 4                       0.113281                        1.428761
# 5                       0.186500                        2.496548
# 6                       0.390668                        4.500191
# 7                       0.233396                        3.462686
# 8                       0.131444                        1.707312
# 9                       0.264344                        3.683930
#
#    recommendation
# 0  Null, en ligne
# 1  Null, en ligne
# 2  Null, en ligne
# 3  Null, en ligne
# 4  Null, en ligne
# 5  Null, en ligne
# 6  Null, en ligne
# 7  Null, en ligne
# 8  Null, en ligne
# 9  Null, en ligne

# %% [markdown]
# ### Implicit Recommender avec nuls sans indicateur, en ligne version batch

# %%
# %%time
ImplicitRecommenderWithNull_no_indicator_online_batch_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull_no_indicator,
                                           n_loop=n_loop, n_pred=n_pred,
                                           online_batch_size=online_batch_size,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 58.4 s, sys: 646 ms, total: 59 s
# Wall time: 1min 10s

# %%
ImplicitRecommenderWithNull_no_indicator_online_batch_df_normalized = \
    normalized_results(ImplicitRecommenderWithNull_no_indicator_online_batch_df, 'Null, en ligne (batch)')
ImplicitRecommenderWithNull_no_indicator_online_batch_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  981.357591   87.640337      305.540323             0.36
# 1  960.815118   79.524320       92.389501             0.40
# 2  957.337154   71.722082      117.689832             0.28
# 3  986.358766   79.385204       68.263953             0.16
# 4  999.301681   81.165717      350.821003             0.39
# 5  981.941627   77.425946      179.532639             0.36
# 6  980.042878   71.451976      217.988383             0.28
# 7  988.382647   59.614288      302.099730             0.36
# 8  995.933466   70.070590       82.715065             0.28
# 9  949.838215   73.237920      234.462037             0.30
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.311345                        3.486298
# 1                       0.096157                        1.161777
# 2                       0.122935                        1.640915
# 3                       0.069208                        0.859908
# 4                       0.351066                        4.322281
# 5                       0.182834                        2.318766
# 6                       0.222427                        3.050838
# 7                       0.305651                        5.067573
# 8                       0.083053                        1.180453
# 9                       0.246844                        3.201375
#
#            recommendation
# 0  Null, en ligne (batch)
# 1  Null, en ligne (batch)
# 2  Null, en ligne (batch)
# 3  Null, en ligne (batch)
# 4  Null, en ligne (batch)
# 5  Null, en ligne (batch)
# 6  Null, en ligne (batch)
# 7  Null, en ligne (batch)
# 8  Null, en ligne (batch)
# 9  Null, en ligne (batch)

# %% [markdown]
# ### Implicit Recommender avec nuls et indicateur binaire, hors ligne

# %%
# %%time
ImplicitRecommenderWithNull_binary_indicator_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull_binary_indicator,
                                           n_loop=n_loop, n_pred=n_pred,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 1min 6s, sys: 713 ms, total: 1min 7s
# Wall time: 1min 29s

# %%
ImplicitRecommenderWithNull_binary_indicator_df_normalized = normalized_results(ImplicitRecommenderWithNull_binary_indicator_df,
                                                                                'Null binaire, hors ligne')
ImplicitRecommenderWithNull_binary_indicator_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  939.906570   73.409844      163.117234             0.25
# 1  999.239368   71.089474       64.924730             0.29
# 2  990.837456   74.169952      237.340162             0.29
# 3  768.012163   57.250785      195.942673             0.32
# 4  972.565481   71.185162      163.081615             0.22
# 5  994.221225   63.359850      137.429396             0.27
# 6  991.977432   74.055141      218.343486             0.29
# 7  966.976131   79.208207      324.816864             0.39
# 8  997.704038   67.118541       71.092050             0.27
# 9  967.495449   58.026806      293.624900             0.36
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.173546                        2.222008
# 1                       0.064974                        0.913282
# 2                       0.239535                        3.199950
# 3                       0.255130                        3.422533
# 4                       0.167682                        2.290950
# 5                       0.138228                        2.169030
# 6                       0.220109                        2.948391
# 7                       0.335910                        4.100798
# 8                       0.071256                        1.059201
# 9                       0.303490                        5.060160
#
#              recommendation
# 0  Null binaire, hors ligne
# 1  Null binaire, hors ligne
# 2  Null binaire, hors ligne
# 3  Null binaire, hors ligne
# 4  Null binaire, hors ligne
# 5  Null binaire, hors ligne
# 6  Null binaire, hors ligne
# 7  Null binaire, hors ligne
# 8  Null binaire, hors ligne
# 9  Null binaire, hors ligne

# %% [markdown]
# ### Implicit Recommender avec nuls et indicateur binaire, en ligne

# %%
# %%time
ImplicitRecommenderWithNull_binary_indicator_online_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull_binary_indicator,
                                           n_loop=n_loop, n_pred=n_pred,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 1min 13s, sys: 683 ms, total: 1min 14s
# Wall time: 1min 27s

# %%
ImplicitRecommenderWithNull_binary_indicator_online_df_normalized = normalized_results(ImplicitRecommenderWithNull_binary_indicator_online_df,
                                                                                       'Null binaire, en ligne')
ImplicitRecommenderWithNull_binary_indicator_online_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  980.739344   68.167225      166.352436             0.21
# 1  969.504367   70.696348      106.181101             0.32
# 2  942.753825   63.313826      141.611772             0.19
# 3  973.511031   66.820756      236.624704             0.35
# 4  986.943080   66.936005      180.051306             0.24
# 5  985.078820   71.881665      122.340871             0.31
# 6  910.777045   58.079563       57.196600             0.28
# 7  984.595523   76.420472      113.245538             0.32
# 8  999.349833   68.560430       92.576408             0.33
# 9  984.897986   82.463890      177.503050             0.22
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.169619                        2.440358
# 1                       0.109521                        1.501932
# 2                       0.150211                        2.236664
# 3                       0.243063                        3.541186
# 4                       0.182433                        2.689902
# 5                       0.124194                        1.701976
# 6                       0.062800                        0.984797
# 7                       0.115017                        1.481874
# 8                       0.092637                        1.350289
# 9                       0.180225                        2.152494
#
#            recommendation
# 0  Null binaire, en ligne
# 1  Null binaire, en ligne
# 2  Null binaire, en ligne
# 3  Null binaire, en ligne
# 4  Null binaire, en ligne
# 5  Null binaire, en ligne
# 6  Null binaire, en ligne
# 7  Null binaire, en ligne
# 8  Null binaire, en ligne
# 9  Null binaire, en ligne

# %% [markdown]
# ### Implicit Recommender avec nuls et indicateur binaire, en ligne version batch

# %%
# %%time
ImplicitRecommenderWithNull_binary_indicator_online_batch_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull_binary_indicator,
                                           n_loop=n_loop, n_pred=n_pred,
                                           online_batch_size=online_batch_size,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 1min 19s, sys: 732 ms, total: 1min 20s
# Wall time: 1min 32s

# %%
ImplicitRecommenderWithNull_binary_indicator_online_batch_df_normalized = \
    normalized_results(ImplicitRecommenderWithNull_binary_indicator_online_batch_df, 'Null binaire, en ligne (batch)')
ImplicitRecommenderWithNull_binary_indicator_online_batch_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  961.384506   62.627427      304.913373             0.38
# 1  998.329365   68.955438       88.367424             0.20
# 2  957.754750   72.368257      227.443665             0.27
# 3  966.074473   64.299806       37.978444             0.26
# 4  967.488928   83.538120      131.933818             0.39
# 5  970.164401   65.478797      265.229811             0.34
# 6  912.667360   74.477402      108.459916             0.40
# 7  996.601054   69.341370       95.789780             0.33
# 8  929.212136   80.119879      111.329969             0.30
# 9  992.712030   72.235114      117.042734             0.36
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.317161                        4.868688
# 1                       0.088515                        1.281515
# 2                       0.237476                        3.142865
# 3                       0.039312                        0.590646
# 4                       0.136367                        1.579325
# 5                       0.273386                        4.050621
# 6                       0.118838                        1.456280
# 7                       0.096116                        1.381423
# 8                       0.119811                        1.389542
# 9                       0.117902                        1.620302
#
#                    recommendation
# 0  Null binaire, en ligne (batch)
# 1  Null binaire, en ligne (batch)
# 2  Null binaire, en ligne (batch)
# 3  Null binaire, en ligne (batch)
# 4  Null binaire, en ligne (batch)
# 5  Null binaire, en ligne (batch)
# 6  Null binaire, en ligne (batch)
# 7  Null binaire, en ligne (batch)
# 8  Null binaire, en ligne (batch)
# 9  Null binaire, en ligne (batch)

# %% [markdown]
# ### Implicit Recommender avec nuls et indicateur special, hors ligne

# %%
# %%time
ImplicitRecommenderWithNull_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull,
                                           n_loop=n_loop, n_pred=n_pred,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 1min 24s, sys: 760 ms, total: 1min 24s
# Wall time: 1min 33s

# %%
ImplicitRecommenderWithNull_df_normalized = normalized_results(ImplicitRecommenderWithNull_df, 'Null special, hors ligne')
ImplicitRecommenderWithNull_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  976.266959   53.932201      181.535563             0.23
# 1  969.046749   80.590884      274.504182             0.32
# 2  992.213472   76.427036      172.700829             0.30
# 3  994.241556   94.761007      308.282773             0.37
# 4  977.306626   69.921156      207.293672             0.25
# 5  962.747701   60.992898      253.800347             0.34
# 6  937.623321   72.018828      278.346281             0.39
# 7  956.742618   78.855812      230.066161             0.29
# 8  993.912691   71.203494       97.460283             0.25
# 9  994.174756   78.021929      246.472597             0.33
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.185949                        3.365996
# 1                       0.283272                        3.406144
# 2                       0.174056                        2.259682
# 3                       0.310068                        3.253266
# 4                       0.212107                        2.964677
# 5                       0.263621                        4.161146
# 6                       0.296864                        3.864910
# 7                       0.240468                        2.917555
# 8                       0.098057                        1.368757
# 9                       0.247917                        3.159017
#
#              recommendation
# 0  Null special, hors ligne
# 1  Null special, hors ligne
# 2  Null special, hors ligne
# 3  Null special, hors ligne
# 4  Null special, hors ligne
# 5  Null special, hors ligne
# 6  Null special, hors ligne
# 7  Null special, hors ligne
# 8  Null special, hors ligne
# 9  Null special, hors ligne

# %% [markdown]
# ### Implicit Recommender avec nuls et indicateur special, en ligne

# %%
# %%time
ImplicitRecommenderWithNull_online_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull,
                                           n_loop=n_loop, n_pred=n_pred,
                                           online_batch_size=1,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 1min 33s, sys: 803 ms, total: 1min 34s
# Wall time: 1min 44s

# %%
ImplicitRecommenderWithNull_online_df_normalized = normalized_results(ImplicitRecommenderWithNull_online_df, 'Null special, en ligne')
ImplicitRecommenderWithNull_online_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  993.535579   78.697664      297.555022             0.34
# 1  889.343352   71.358040       71.352323             0.30
# 2  961.442391   68.471930      194.625129             0.27
# 3  985.731746   78.025155      271.077836             0.34
# 4  979.809690   76.352991      139.831921             0.23
# 5  992.795853   72.333716      256.988671             0.31
# 6  984.251889   75.420819      212.750514             0.29
# 7  950.388415   75.020805      235.172022             0.31
# 8  989.661670   73.097547      323.298564             0.39
# 9  983.709041   71.731863      226.242283             0.30
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.299491                        3.780989
# 1                       0.080230                        0.999920
# 2                       0.202430                        2.842408
# 3                       0.275002                        3.474236
# 4                       0.142713                        1.831388
# 5                       0.258853                        3.552820
# 6                       0.216155                        2.820846
# 7                       0.247448                        3.134757
# 8                       0.326676                        4.422837
# 9                       0.229989                        3.154000
#
#            recommendation
# 0  Null special, en ligne
# 1  Null special, en ligne
# 2  Null special, en ligne
# 3  Null special, en ligne
# 4  Null special, en ligne
# 5  Null special, en ligne
# 6  Null special, en ligne
# 7  Null special, en ligne
# 8  Null special, en ligne
# 9  Null special, en ligne

# %% [markdown]
# ### Implicit Recommender avec nuls et indicateur special, en ligne version batch

# %%
# %%time
ImplicitRecommenderWithNull_online_batch_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull,
                                           n_loop=n_loop, n_pred=n_pred,
                                           online_batch_size=online_batch_size,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 1min 40s, sys: 759 ms, total: 1min 41s
# Wall time: 2min 1s

# %%
ImplicitRecommenderWithNull_online_batch_df_normalized = \
    normalized_results(ImplicitRecommenderWithNull_online_batch_df, 'Null special, en ligne (batch)')
ImplicitRecommenderWithNull_online_batch_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  934.198291   69.651051      136.373001             0.24
# 1  988.776425   67.774755      151.632779             0.24
# 2  995.454266   82.541637      172.817732             0.25
# 3  996.112668   64.039142      180.911395             0.27
# 4  952.545801   65.239406      257.118256             0.32
# 5  986.132007   74.736158      223.596304             0.29
# 6  991.562008   61.882849      213.199197             0.28
# 7  952.167620   74.535208      282.883858             0.44
# 8  991.631506   73.578608       83.406072             0.35
# 9  947.767427   83.775058      272.494933             0.35
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.145979                        1.957946
# 1                       0.153354                        2.237305
# 2                       0.173607                        2.093704
# 3                       0.181617                        2.825013
# 4                       0.269927                        3.941150
# 5                       0.226741                        2.991809
# 6                       0.215013                        3.445207
# 7                       0.297095                        3.795305
# 8                       0.084110                        1.133564
# 9                       0.287512                        3.252698
#
#                    recommendation
# 0  Null special, en ligne (batch)
# 1  Null special, en ligne (batch)
# 2  Null special, en ligne (batch)
# 3  Null special, en ligne (batch)
# 4  Null special, en ligne (batch)
# 5  Null special, en ligne (batch)
# 6  Null special, en ligne (batch)
# 7  Null special, en ligne (batch)
# 8  Null special, en ligne (batch)
# 9  Null special, en ligne (batch)

# %% [markdown]
# ### Fully Implicit Recommender Simple, hors ligne

# %%
# %%time
FullyImplicitRecommenderSimple_df = eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartFullyImplicitRecommender,
                                                                      ImplicitRecommenderClass=ImplicitRecommenderSimple, 
                                                                      n_loop=n_loop, n_pred=n_pred,
                                                                      user_dim=user_dim, item_dim=item_dim,
                                                                      n_hidden=n_hidden, hidden_size=hidden_size, 
                                                                      dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 22.6 s, sys: 180 ms, total: 22.8 s
# Wall time: 33.4 s

# %%
FullyImplicitRecommenderSimple_df_normalized = normalized_results(FullyImplicitRecommenderSimple_df, 'Fully Implicit Simple, hors ligne')
FullyImplicitRecommenderSimple_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  992.651771   80.274909      253.583186             0.40
# 1  992.704254   69.880528      215.497910             0.35
# 2  973.430045   66.188986      214.844512             0.33
# 3  987.815364   71.533747      198.602764             0.39
# 4  821.479482   59.201016      185.257775             0.42
# 5  975.877162   69.606900      121.438036             0.27
# 6  994.213779   69.314248      201.573085             0.29
# 7  973.798054   79.939456      199.869294             0.30
# 8  969.586913   80.233126      150.738899             0.35
# 9  969.624857   80.187657      177.535734             0.32
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.255460                        3.158935
# 1                       0.217082                        3.083805
# 2                       0.220709                        3.245925
# 3                       0.201053                        2.776351
# 4                       0.225517                        3.129301
# 5                       0.124440                        1.744626
# 6                       0.202746                        2.908105
# 7                       0.205247                        2.500258
# 8                       0.155467                        1.878761
# 9                       0.183097                        2.214003
#
#                       recommendation
# 0  Fully Implicit Simple, hors ligne
# 1  Fully Implicit Simple, hors ligne
# 2  Fully Implicit Simple, hors ligne
# 3  Fully Implicit Simple, hors ligne
# 4  Fully Implicit Simple, hors ligne
# 5  Fully Implicit Simple, hors ligne
# 6  Fully Implicit Simple, hors ligne
# 7  Fully Implicit Simple, hors ligne
# 8  Fully Implicit Simple, hors ligne
# 9  Fully Implicit Simple, hors ligne

# %% [markdown]
# ### Fully Implicit Recommender Simple, en ligne

# %%
# %%time
FullyImplicitRecommenderSimple_online_df = eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartFullyImplicitRecommender,
                                                                             ImplicitRecommenderClass=ImplicitRecommenderSimple,
                                                                             n_loop=n_loop, n_pred=n_pred,
                                                                             online_batch_size=1,
                                                                             user_dim=user_dim, item_dim=item_dim,
                                                                             n_hidden=n_hidden, hidden_size=hidden_size, 
                                                                             dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 22.9 s, sys: 199 ms, total: 23.1 s
# Wall time: 34.3 s

# %%
FullyImplicitRecommenderSimple_online_df_normalized = normalized_results(FullyImplicitRecommenderSimple_online_df, 'Fully Implicit Simple, en ligne')
FullyImplicitRecommenderSimple_online_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  989.773969   70.752858      215.740050             0.42
# 1  987.380928   68.129398      169.348114             0.28
# 2  990.233741   73.977356      208.721105             0.33
# 3  965.849636   65.031678      145.973292             0.29
# 4  978.466504   75.327849      166.006351             0.28
# 5  958.723540   67.539273      118.021506             0.29
# 6  969.567952   81.555003      226.395871             0.35
# 7  999.704752   86.088826      138.789250             0.24
# 8  988.086156   70.859867      174.856407             0.29
# 9  997.469469   75.692548      240.474211             0.41
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.217969                        3.049206
# 1                       0.171512                        2.485683
# 2                       0.210780                        2.821419
# 3                       0.151135                        2.244649
# 4                       0.169660                        2.203785
# 5                       0.123103                        1.747450
# 6                       0.233502                        2.775990
# 7                       0.138830                        1.612163
# 8                       0.176965                        2.467637
# 9                       0.241084                        3.176987
#
#                     recommendation
# 0  Fully Implicit Simple, en ligne
# 1  Fully Implicit Simple, en ligne
# 2  Fully Implicit Simple, en ligne
# 3  Fully Implicit Simple, en ligne
# 4  Fully Implicit Simple, en ligne
# 5  Fully Implicit Simple, en ligne
# 6  Fully Implicit Simple, en ligne
# 7  Fully Implicit Simple, en ligne
# 8  Fully Implicit Simple, en ligne
# 9  Fully Implicit Simple, en ligne

# %% [markdown]
# ### Fully Implicit Recommender Simple, en ligne version batch

# %%
# %%time
FullyImplicitRecommenderSimple_online_batch_df = eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartFullyImplicitRecommender,
                                                                             ImplicitRecommenderClass=ImplicitRecommenderSimple,
                                                                             n_loop=n_loop, n_pred=n_pred,
                                                                             online_batch_size=online_batch_size,
                                                                             user_dim=user_dim, item_dim=item_dim,
                                                                             n_hidden=n_hidden, hidden_size=hidden_size, 
                                                                             dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 21.8 s, sys: 199 ms, total: 22 s
# Wall time: 38.8 s

# %%
FullyImplicitRecommenderSimple_online_batch_df_normalized = normalized_results(FullyImplicitRecommenderSimple_online_batch_df, 'Fully Implicit Simple, en ligne (batch)')
FullyImplicitRecommenderSimple_online_batch_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  997.942636   68.588068      191.256489             0.36
# 1  966.290327   77.082980      222.617568             0.41
# 2  953.336856   69.085402      189.136151             0.35
# 3  979.712880   69.649358      161.716412             0.27
# 4  956.877129   68.594667      201.477658             0.30
# 5  988.795922   80.949563      203.368567             0.27
# 6  989.680674   69.614588      207.233203             0.42
# 7  992.109051   66.890780      153.896882             0.32
# 8  979.032168   74.229058      113.232680             0.17
# 9  967.686683   73.919845      153.816484             0.30
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.191651                        2.788480
# 1                       0.230384                        2.888025
# 2                       0.198394                        2.737715
# 3                       0.165065                        2.321865
# 4                       0.210558                        2.937220
# 5                       0.205673                        2.512287
# 6                       0.209394                        2.976865
# 7                       0.155121                        2.300719
# 8                       0.115658                        1.525450
# 9                       0.158953                        2.080855
#
#                             recommendation
# 0  Fully Implicit Simple, en ligne (batch)
# 1  Fully Implicit Simple, en ligne (batch)
# 2  Fully Implicit Simple, en ligne (batch)
# 3  Fully Implicit Simple, en ligne (batch)
# 4  Fully Implicit Simple, en ligne (batch)
# 5  Fully Implicit Simple, en ligne (batch)
# 6  Fully Implicit Simple, en ligne (batch)
# 7  Fully Implicit Simple, en ligne (batch)
# 8  Fully Implicit Simple, en ligne (batch)
# 9  Fully Implicit Simple, en ligne (batch)

# %% [markdown]
# ### Fully Implicit Recommender avec nuls sans indicateur, hors ligne

# %%
# %%time
FullyImplicitRecommenderWithNull_no_indicator_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartFullyImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull_no_indicator, 
                                           n_loop=n_loop, n_pred=n_pred,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 21.9 s, sys: 209 ms, total: 22.1 s
# Wall time: 34.3 s

# %%
FullyImplicitRecommenderWithNull_no_indicator_df_normalized = normalized_results(FullyImplicitRecommenderWithNull_no_indicator_df, 'Fully Implicit Null, hors ligne')
FullyImplicitRecommenderWithNull_no_indicator_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  969.331923   74.189542      167.708529             0.32
# 1  985.947796   63.885437      125.247149             0.26
# 2  890.268926   64.224578      156.306327             0.34
# 3  927.526435   73.197475      192.010207             0.36
# 4  985.045392   77.830823      187.616568             0.29
# 5  964.517854   70.859016      126.765040             0.22
# 6  987.388856   80.918198      137.391353             0.26
# 7  993.475774   81.395931      137.267966             0.30
# 8  985.166218   84.999731      172.035320             0.25
# 9  962.649625   76.463913      246.195761             0.35
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.173015                        2.260541
# 1                       0.127032                        1.960496
# 2                       0.175572                        2.433746
# 3                       0.207013                        2.623181
# 4                       0.190465                        2.410569
# 5                       0.131428                        1.788975
# 6                       0.139146                        1.697904
# 7                       0.138169                        1.686423
# 8                       0.174626                        2.023951
# 9                       0.255748                        3.219764
#
#                     recommendation
# 0  Fully Implicit Null, hors ligne
# 1  Fully Implicit Null, hors ligne
# 2  Fully Implicit Null, hors ligne
# 3  Fully Implicit Null, hors ligne
# 4  Fully Implicit Null, hors ligne
# 5  Fully Implicit Null, hors ligne
# 6  Fully Implicit Null, hors ligne
# 7  Fully Implicit Null, hors ligne
# 8  Fully Implicit Null, hors ligne
# 9  Fully Implicit Null, hors ligne

# %% [markdown]
# ### Fully Implicit Recommender avec nuls sans indicateur, en ligne

# %%
# %%time
FullyImplicitRecommenderWithNull_no_indicator_online_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartFullyImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull_no_indicator,
                                           n_loop=n_loop, n_pred=n_pred,
                                           online_batch_size=1,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 21.6 s, sys: 158 ms, total: 21.8 s
# Wall time: 32.3 s

# %%
FullyImplicitRecommenderWithNull_no_indicator_online_df_normalized = normalized_results(FullyImplicitRecommenderWithNull_no_indicator_online_df,
                                                                                   'Fully Implicit Null, en ligne')
FullyImplicitRecommenderWithNull_no_indicator_online_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  938.338863   76.122699      156.590745             0.32
# 1  961.585969   69.541308      252.222427             0.39
# 2  982.805260   75.312749      203.984480             0.29
# 3  910.646538   75.542047      164.989913             0.31
# 4  978.294493   73.337514      135.906221             0.24
# 5  978.527447   78.282657      189.403401             0.34
# 6  996.024466   76.202433      148.295882             0.27
# 7  957.749155   60.336954      166.995909             0.38
# 8  989.303831   66.814617      139.845076             0.30
# 9  913.349470   71.839493      140.694763             0.26
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.166881                        2.057083
# 1                       0.262298                        3.626944
# 2                       0.207553                        2.708499
# 3                       0.181179                        2.184081
# 4                       0.138922                        1.853161
# 5                       0.193560                        2.419481
# 6                       0.148888                        1.946078
# 7                       0.174363                        2.767722
# 8                       0.141357                        2.093031
# 9                       0.154043                        1.958460
#
#                   recommendation
# 0  Fully Implicit Null, en ligne
# 1  Fully Implicit Null, en ligne
# 2  Fully Implicit Null, en ligne
# 3  Fully Implicit Null, en ligne
# 4  Fully Implicit Null, en ligne
# 5  Fully Implicit Null, en ligne
# 6  Fully Implicit Null, en ligne
# 7  Fully Implicit Null, en ligne
# 8  Fully Implicit Null, en ligne
# 9  Fully Implicit Null, en ligne

# %% [markdown]
# ### Fully Implicit Recommender avec nuls sans indicateur, en ligne version batch

# %%
# %%time
FullyImplicitRecommenderWithNull_no_indicator_online_batch_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartFullyImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull_no_indicator,
                                           n_loop=n_loop, n_pred=n_pred,
                                           online_batch_size=online_batch_size,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 21.8 s, sys: 201 ms, total: 22 s
# Wall time: 32.2 s

# %%
FullyImplicitRecommenderWithNull_no_indicator_online_batch_df_normalized = \
    normalized_results(FullyImplicitRecommenderWithNull_no_indicator_online_batch_df, 'Fully Implicit Null, en ligne (batch)')
FullyImplicitRecommenderWithNull_no_indicator_online_batch_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  902.742085   72.310872      213.439501             0.35
# 1  995.807997   82.688206      233.354047             0.31
# 2  993.714307   73.188397      202.817784             0.33
# 3  984.444422   75.290803       94.718755             0.21
# 4  994.328566   62.319306      187.878114             0.38
# 5  916.648635   75.430824      212.608535             0.39
# 6  973.577473   84.479791      236.863704             0.32
# 7  991.445892   64.914036      103.857855             0.25
# 8  992.104195   70.169982      179.180244             0.33
# 9  985.933750   67.238583      190.216544             0.45
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.236435                        2.951693
# 1                       0.234336                        2.822096
# 2                       0.204101                        2.771174
# 3                       0.096215                        1.258039
# 4                       0.188950                        3.014766
# 5                       0.231941                        2.818590
# 6                       0.243292                        2.803791
# 7                       0.104754                        1.599929
# 8                       0.180606                        2.553517
# 9                       0.192930                        2.828979
#
#                           recommendation
# 0  Fully Implicit Null, en ligne (batch)
# 1  Fully Implicit Null, en ligne (batch)
# 2  Fully Implicit Null, en ligne (batch)
# 3  Fully Implicit Null, en ligne (batch)
# 4  Fully Implicit Null, en ligne (batch)
# 5  Fully Implicit Null, en ligne (batch)
# 6  Fully Implicit Null, en ligne (batch)
# 7  Fully Implicit Null, en ligne (batch)
# 8  Fully Implicit Null, en ligne (batch)
# 9  Fully Implicit Null, en ligne (batch)

# %% [markdown]
# ### Fully Implicit Recommender avec nuls et indicateur binaire, hors ligne

# %%
# %%time
FullyImplicitRecommenderWithNull_binary_indicator_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartFullyImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull_binary_indicator,
                                           n_loop=n_loop, n_pred=n_pred,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 21.9 s, sys: 147 ms, total: 22.1 s
# Wall time: 32.2 s

# %%
FullyImplicitRecommenderWithNull_binary_indicator_df_normalized = normalized_results(FullyImplicitRecommenderWithNull_binary_indicator_df,
                                                                                'Fully Implicit Null binaire, hors ligne')
FullyImplicitRecommenderWithNull_binary_indicator_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  942.243330   76.102243      133.785147             0.25
# 1  965.838659   64.140582      132.511910             0.26
# 2  987.243338   78.866723      167.264242             0.29
# 3  982.664980   73.028761      178.914318             0.30
# 4  984.364318   75.143304      188.194223             0.35
# 5  982.601981   66.816772      230.690829             0.40
# 6  989.563807   69.863206      153.394251             0.30
# 7  989.710575   68.005513      138.558095             0.32
# 8  983.117456   75.605808      249.478231             0.38
# 9  967.558039   73.049247      196.201603             0.30
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.141986                        1.757966
# 1                       0.137199                        2.065961
# 2                       0.169426                        2.120847
# 3                       0.182071                        2.449916
# 4                       0.191184                        2.504471
# 5                       0.234775                        3.452589
# 6                       0.155012                        2.195637
# 7                       0.139999                        2.037454
# 8                       0.253762                        3.299723
# 9                       0.202780                        2.685881
#
#                             recommendation
# 0  Fully Implicit Null binaire, hors ligne
# 1  Fully Implicit Null binaire, hors ligne
# 2  Fully Implicit Null binaire, hors ligne
# 3  Fully Implicit Null binaire, hors ligne
# 4  Fully Implicit Null binaire, hors ligne
# 5  Fully Implicit Null binaire, hors ligne
# 6  Fully Implicit Null binaire, hors ligne
# 7  Fully Implicit Null binaire, hors ligne
# 8  Fully Implicit Null binaire, hors ligne
# 9  Fully Implicit Null binaire, hors ligne

# %% [markdown]
# ### Fully Implicit Recommender avec nuls et indicateur binaire, en ligne

# %%
# %%time
FullyImplicitRecommenderWithNull_binary_indicator_online_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartFullyImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull_binary_indicator,
                                           n_loop=n_loop, n_pred=n_pred,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 22.3 s, sys: 175 ms, total: 22.5 s
# Wall time: 33.5 s

# %%
FullyImplicitRecommenderWithNull_binary_indicator_online_df_normalized = normalized_results(FullyImplicitRecommenderWithNull_binary_indicator_online_df,
                                                                                       'Fully Implicit Null binaire, en ligne')
FullyImplicitRecommenderWithNull_binary_indicator_online_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  983.843291   66.271063      155.377254             0.29
# 1  923.380636   74.789420      186.914580             0.39
# 2  949.255560   81.725358      230.612092             0.30
# 3  998.427543   75.457659      248.172828             0.42
# 4  983.341448   60.262429      117.871745             0.28
# 5  993.232717   70.402084      169.262297             0.30
# 6  974.808225   71.047534      137.626671             0.29
# 7  949.879988   67.317482      117.076453             0.30
# 8  983.685404   66.673681      199.444894             0.28
# 9  982.228871   78.119004      200.096720             0.30
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.157929                        2.344572
# 1                       0.202424                        2.499212
# 2                       0.242940                        2.821794
# 3                       0.248564                        3.288902
# 4                       0.119869                        1.955974
# 5                       0.170416                        2.404223
# 6                       0.141183                        1.937107
# 7                       0.123254                        1.739169
# 8                       0.202753                        2.991359
# 9                       0.203717                        2.561435
#
#                           recommendation
# 0  Fully Implicit Null binaire, en ligne
# 1  Fully Implicit Null binaire, en ligne
# 2  Fully Implicit Null binaire, en ligne
# 3  Fully Implicit Null binaire, en ligne
# 4  Fully Implicit Null binaire, en ligne
# 5  Fully Implicit Null binaire, en ligne
# 6  Fully Implicit Null binaire, en ligne
# 7  Fully Implicit Null binaire, en ligne
# 8  Fully Implicit Null binaire, en ligne
# 9  Fully Implicit Null binaire, en ligne

# %% [markdown]
# ### Fully Implicit Recommender avec nuls et indicateur binaire, en ligne version batch

# %%
# %%time
FullyImplicitRecommenderWithNull_binary_indicator_online_batch_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartFullyImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull_binary_indicator,
                                           n_loop=n_loop, n_pred=n_pred,
                                           online_batch_size=online_batch_size,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 22.8 s, sys: 180 ms, total: 23 s
# Wall time: 35.2 s

# %%
FullyImplicitRecommenderWithNull_binary_indicator_online_batch_df_normalized = \
    normalized_results(FullyImplicitRecommenderWithNull_binary_indicator_online_batch_df, 'Fully Implicit Null binaire, en ligne (batch)')
FullyImplicitRecommenderWithNull_binary_indicator_online_batch_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  918.492456   52.805143      180.969552             0.40
# 1  975.593134   75.045986      184.779185             0.30
# 2  988.973669   69.682103      230.036074             0.33
# 3  976.853721   74.476388      172.874233             0.33
# 4  968.759370   86.775230      233.356926             0.30
# 5  993.110567   76.929469      166.394331             0.27
# 6  992.416100   78.101643      239.212715             0.34
# 7  971.823259   81.238052      240.383941             0.32
# 8  936.443096   71.036504      130.027844             0.30
# 9  999.457700   70.942922      208.738361             0.32
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.197029                        3.427120
# 1                       0.189402                        2.462213
# 2                       0.232601                        3.301222
# 3                       0.176970                        2.321195
# 4                       0.240882                        2.689211
# 5                       0.167549                        2.162947
# 6                       0.241041                        3.062838
# 7                       0.247354                        2.959007
# 8                       0.138853                        1.830437
# 9                       0.208852                        2.942342
#
#                                   recommendation
# 0  Fully Implicit Null binaire, en ligne (batch)
# 1  Fully Implicit Null binaire, en ligne (batch)
# 2  Fully Implicit Null binaire, en ligne (batch)
# 3  Fully Implicit Null binaire, en ligne (batch)
# 4  Fully Implicit Null binaire, en ligne (batch)
# 5  Fully Implicit Null binaire, en ligne (batch)
# 6  Fully Implicit Null binaire, en ligne (batch)
# 7  Fully Implicit Null binaire, en ligne (batch)
# 8  Fully Implicit Null binaire, en ligne (batch)
# 9  Fully Implicit Null binaire, en ligne (batch)

# %% [markdown]
# ### Fully Implicit Recommender avec nuls et indicateur special, hors ligne

# %%
# %%time
FullyImplicitRecommenderWithNull_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartFullyImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull,
                                           n_loop=n_loop, n_pred=n_pred,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 23.1 s, sys: 207 ms, total: 23.3 s
# Wall time: 38.4 s

# %%
FullyImplicitRecommenderWithNull_df_normalized = normalized_results(FullyImplicitRecommenderWithNull_df, 'Fully Implicit Null special, hors ligne')
FullyImplicitRecommenderWithNull_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  990.042147   65.724632      132.912646             0.36
# 1  998.440319   79.648861      162.617886             0.30
# 2  985.499274   71.314151      125.615983             0.28
# 3  954.320471   60.647881      107.654463             0.28
# 4  997.258116   72.042600      189.940337             0.40
# 5  986.435821   77.132882      213.603055             0.29
# 6  987.640873   63.259334      151.447456             0.38
# 7  840.054675   53.084713      117.841293             0.28
# 8  990.192061   69.598915      187.491798             0.34
# 9  995.639330   76.843181      218.788158             0.36
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.134249                        2.022265
# 1                       0.162872                        2.041685
# 2                       0.127464                        1.761445
# 3                       0.112807                        1.775074
# 4                       0.190463                        2.636500
# 5                       0.216540                        2.769287
# 6                       0.153343                        2.394073
# 7                       0.140278                        2.219872
# 8                       0.189349                        2.693890
# 9                       0.219746                        2.847203
#
#                             recommendation
# 0  Fully Implicit Null special, hors ligne
# 1  Fully Implicit Null special, hors ligne
# 2  Fully Implicit Null special, hors ligne
# 3  Fully Implicit Null special, hors ligne
# 4  Fully Implicit Null special, hors ligne
# 5  Fully Implicit Null special, hors ligne
# 6  Fully Implicit Null special, hors ligne
# 7  Fully Implicit Null special, hors ligne
# 8  Fully Implicit Null special, hors ligne
# 9  Fully Implicit Null special, hors ligne

# %% [markdown]
# ### Fully Implicit Recommender avec nuls et indicateur special, en ligne

# %%
# %%time
FullyImplicitRecommenderWithNull_online_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartFullyImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull,
                                           n_loop=n_loop, n_pred=n_pred,
                                           online_batch_size=1,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 23.5 s, sys: 190 ms, total: 23.6 s
# Wall time: 49.2 s

# %%
FullyImplicitRecommenderWithNull_online_df_normalized = normalized_results(FullyImplicitRecommenderWithNull_online_df, 'Fully Implicit Null special, en ligne')
FullyImplicitRecommenderWithNull_online_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  921.926390   70.288489      194.888807             0.38
# 1  965.138349   72.999402      157.041146             0.32
# 2  986.115738   77.096698      104.551409             0.28
# 3  998.243491   78.605075      184.181030             0.34
# 4  959.638874   74.616035      200.772971             0.35
# 5  993.952225   63.876174      142.100663             0.27
# 6  976.071295   76.314993      182.753466             0.30
# 7  936.691365   73.039079      197.230085             0.26
# 8  987.934193   66.480624      117.763527             0.27
# 9  820.801536   72.294852      118.857967             0.29
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.211393                        2.772699
# 1                       0.162714                        2.151266
# 2                       0.106023                        1.356107
# 3                       0.184505                        2.343119
# 4                       0.209217                        2.690748
# 5                       0.142965                        2.224627
# 6                       0.187234                        2.394726
# 7                       0.210560                        2.700336
# 8                       0.119202                        1.771396
# 9                       0.144807                        1.644072
#
#                           recommendation
# 0  Fully Implicit Null special, en ligne
# 1  Fully Implicit Null special, en ligne
# 2  Fully Implicit Null special, en ligne
# 3  Fully Implicit Null special, en ligne
# 4  Fully Implicit Null special, en ligne
# 5  Fully Implicit Null special, en ligne
# 6  Fully Implicit Null special, en ligne
# 7  Fully Implicit Null special, en ligne
# 8  Fully Implicit Null special, en ligne
# 9  Fully Implicit Null special, en ligne

# %% [markdown]
# ### Fully Implicit Recommender avec nuls et indicateur special, en ligne version batch

# %%
# %%time
FullyImplicitRecommenderWithNull_online_batch_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartFullyImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull,
                                           n_loop=n_loop, n_pred=n_pred,
                                           online_batch_size=online_batch_size,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 23.4 s, sys: 182 ms, total: 23.6 s
# Wall time: 48.3 s

# %%
FullyImplicitRecommenderWithNull_online_batch_df_normalized = \
    normalized_results(FullyImplicitRecommenderWithNull_online_batch_df, 'Fully Implicit Null special, en ligne (batch)')
FullyImplicitRecommenderWithNull_online_batch_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  926.072070   71.867006      219.289561             0.37
# 1  963.006486   61.796188      193.100223             0.31
# 2  995.564832   74.114114      200.606469             0.34
# 3  985.733381   81.029192      200.943677             0.33
# 4  967.993626   61.153807      117.678106             0.25
# 5  983.651659   78.050242      224.040164             0.35
# 6  970.810402   70.528831      141.323845             0.30
# 7  952.348217   78.684022      221.160553             0.35
# 8  990.373906   78.639512      189.630616             0.34
# 9  985.319040   78.593223      151.427677             0.25
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.236795                        3.051325
# 1                       0.200518                        3.124792
# 2                       0.201500                        2.706724
# 3                       0.203852                        2.479892
# 4                       0.121569                        1.924297
# 5                       0.227764                        2.870461
# 6                       0.145573                        2.003774
# 7                       0.232227                        2.810743
# 8                       0.191474                        2.411391
# 9                       0.153684                        1.926727
#
#                                   recommendation
# 0  Fully Implicit Null special, en ligne (batch)
# 1  Fully Implicit Null special, en ligne (batch)
# 2  Fully Implicit Null special, en ligne (batch)
# 3  Fully Implicit Null special, en ligne (batch)
# 4  Fully Implicit Null special, en ligne (batch)
# 5  Fully Implicit Null special, en ligne (batch)
# 6  Fully Implicit Null special, en ligne (batch)
# 7  Fully Implicit Null special, en ligne (batch)
# 8  Fully Implicit Null special, en ligne (batch)
# 9  Fully Implicit Null special, en ligne (batch)

# %% [markdown]
# ## Aggregation des résutats

# %%
all_results = pd.concat( (
    ImplicitRecommenderSimple_df_normalized,
    ImplicitRecommenderSimple_online_df_normalized,
    ImplicitRecommenderSimple_online_batch_df_normalized,
    ImplicitRecommenderWithNull_no_indicator_df_normalized,
    ImplicitRecommenderWithNull_no_indicator_online_df_normalized,
    ImplicitRecommenderWithNull_no_indicator_online_batch_df_normalized,
    ImplicitRecommenderWithNull_binary_indicator_df_normalized,
    ImplicitRecommenderWithNull_binary_indicator_online_df_normalized,
    ImplicitRecommenderWithNull_binary_indicator_online_batch_df_normalized,
    ImplicitRecommenderWithNull_df_normalized,
    ImplicitRecommenderWithNull_online_df_normalized,
    ImplicitRecommenderWithNull_online_batch_df_normalized,
    
    FullyImplicitRecommenderSimple_df_normalized,
    FullyImplicitRecommenderSimple_online_df_normalized,
    FullyImplicitRecommenderSimple_online_batch_df_normalized,
    FullyImplicitRecommenderWithNull_no_indicator_df_normalized,
    FullyImplicitRecommenderWithNull_no_indicator_online_df_normalized,
    FullyImplicitRecommenderWithNull_no_indicator_online_batch_df_normalized,
    FullyImplicitRecommenderWithNull_binary_indicator_df_normalized,
    FullyImplicitRecommenderWithNull_binary_indicator_online_df_normalized,
    FullyImplicitRecommenderWithNull_binary_indicator_online_batch_df_normalized,
    FullyImplicitRecommenderWithNull_df_normalized,
    FullyImplicitRecommenderWithNull_online_df_normalized,
    FullyImplicitRecommenderWithNull_online_batch_df_normalized
), axis = 0)

# %%
aggregat = all_results.groupby('recommendation').mean()

# %% [markdown]
# ### Classement ratio de recommandations effectives

# %%
col = 'good_reco_ratio' 
aggregat.sort_values(col, ascending=False)\
    .style.apply((lambda x: ['background: lightgreen' if x.name == col else '' for _ in x]))
# Out:
# <style  type="text/css" >
#     #T_fe0e3758_3b47_11e9_8116_853153767eb5row0_col3 {
#             background:  lightgreen;
#         }    #T_fe0e3758_3b47_11e9_8116_853153767eb5row1_col3 {
#             background:  lightgreen;
#         }    #T_fe0e3758_3b47_11e9_8116_853153767eb5row2_col3 {
#             background:  lightgreen;
#         }    #T_fe0e3758_3b47_11e9_8116_853153767eb5row3_col3 {
#             background:  lightgreen;
#         }    #T_fe0e3758_3b47_11e9_8116_853153767eb5row4_col3 {
#             background:  lightgreen;
#         }    #T_fe0e3758_3b47_11e9_8116_853153767eb5row5_col3 {
#             background:  lightgreen;
#         }    #T_fe0e3758_3b47_11e9_8116_853153767eb5row6_col3 {
#             background:  lightgreen;
#         }    #T_fe0e3758_3b47_11e9_8116_853153767eb5row7_col3 {
#             background:  lightgreen;
#         }    #T_fe0e3758_3b47_11e9_8116_853153767eb5row8_col3 {
#             background:  lightgreen;
#         }    #T_fe0e3758_3b47_11e9_8116_853153767eb5row9_col3 {
#             background:  lightgreen;
#         }    #T_fe0e3758_3b47_11e9_8116_853153767eb5row10_col3 {
#             background:  lightgreen;
#         }    #T_fe0e3758_3b47_11e9_8116_853153767eb5row11_col3 {
#             background:  lightgreen;
#         }    #T_fe0e3758_3b47_11e9_8116_853153767eb5row12_col3 {
#             background:  lightgreen;
#         }    #T_fe0e3758_3b47_11e9_8116_853153767eb5row13_col3 {
#             background:  lightgreen;
#         }    #T_fe0e3758_3b47_11e9_8116_853153767eb5row14_col3 {
#             background:  lightgreen;
#         }    #T_fe0e3758_3b47_11e9_8116_853153767eb5row15_col3 {
#             background:  lightgreen;
#         }    #T_fe0e3758_3b47_11e9_8116_853153767eb5row16_col3 {
#             background:  lightgreen;
#         }    #T_fe0e3758_3b47_11e9_8116_853153767eb5row17_col3 {
#             background:  lightgreen;
#         }    #T_fe0e3758_3b47_11e9_8116_853153767eb5row18_col3 {
#             background:  lightgreen;
#         }    #T_fe0e3758_3b47_11e9_8116_853153767eb5row19_col3 {
#             background:  lightgreen;
#         }    #T_fe0e3758_3b47_11e9_8116_853153767eb5row20_col3 {
#             background:  lightgreen;
#         }    #T_fe0e3758_3b47_11e9_8116_853153767eb5row21_col3 {
#             background:  lightgreen;
#         }    #T_fe0e3758_3b47_11e9_8116_853153767eb5row22_col3 {
#             background:  lightgreen;
#         }    #T_fe0e3758_3b47_11e9_8116_853153767eb5row23_col3 {
#             background:  lightgreen;
#         }</style><table id="T_fe0e3758_3b47_11e9_8116_853153767eb5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >max_price</th>        <th class="col_heading level0 col1" >mean_price</th>        <th class="col_heading level0 col2" >average_reward</th>        <th class="col_heading level0 col3" >good_reco_ratio</th>        <th class="col_heading level0 col4" >average_reward_normalized_max</th>        <th class="col_heading level0 col5" >average_reward_normalized_mean</th>    </tr>    <tr>        <th class="index_name level0" >recommendation</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fe0e3758_3b47_11e9_8116_853153767eb5level0_row0" class="row_heading level0 row0" >Fully Implicit Simple, hors ligne</th>
#                         <td id="T_fe0e3758_3b47_11e9_8116_853153767eb5row0_col0" class="data row0 col0" >965.118</td>
#                         <td id="T_fe0e3758_3b47_11e9_8116_853153767eb5row0_col1" class="data row0 col1" >72.6361</td>
#                         <td id="T_fe0e3758_3b47_11e9_8116_853153767eb5row0_col2" class="data row0 col2" >191.894</td>
#                         <td id="T_fe0e3758_3b47_11e9_8116_853153767eb5row0_col3" class="data row0 col3" >0.342</td>
#                         <td id="T_fe0e3758_3b47_11e9_8116_853153767eb5row0_col4" class="data row0 col4" >0.199082</td>
#                         <td id="T_fe0e3758_3b47_11e9_8116_853153767eb5row0_col5" class="data row0 col5" >2.66401</td>
#             </tr>
#             <tr>
#                         <th id="T_fe0e3758_3b47_11e9_8116_853153767eb5level0_row1" class="row_heading level0 row1" >Null, en ligne</th>
#                         <td id="T_fe0e3758_3b47_11e9_8116_853153767eb5row1_col0" class="data row1 col0" >952.328</td>
#                         <td id="T_fe0e3758_3b47_11e9_8116_853153767eb5row1_col1" class="data row1 col1" >69.9315</td>
#                         <td id="T_fe0e3758_3b47_11e9_8116_853153767eb5row1_col2" class="data row1 col2" >195.544</td>
#                         <td id="T_fe0e3758_3b47_11e9_8116_853153767eb5row1_col3" class="data row1 col3" >0.338</td>
#                         <td id="T_fe0e3758_3b47_11e9_8116_853153767eb5row1_col4" class="data row1 col4" >0.204616</td>
#                         <td id="T_fe0e3758_3b47_11e9_8116_853153767eb5row1_col5" class="data row1 col5" >2.77229</td>
#             </tr>
#             <tr>
#                         <th id="T_fe0e3758_3b47_11e9_8116_853153767eb5level0_row2" class="row_heading level0 row2" >Simple, hors ligne</th>
#                         <td id="T_fe0e3758_3b47_11e9_8116_853153767eb5row2_col0" class="data row2 col0" >978.586</td>
#                         <td id="T_fe0e3758_3b47_11e9_8116_853153767eb5row2_col1" class="data row2 col1" >73.7213</td>
#                         <td id="T_fe0e3758_3b47_11e9_8116_853153767eb5row2_col2" class="data row2 col2" >95.5285</td>
#                         <td id="T_fe0e3758_3b47_11e9_8116_853153767eb5row2_col3" class="data row2 col3" >0.333</td>
#                         <td id="T_fe0e3758_3b47_11e9_8116_853153767eb5row2_col4" class="data row2 col4" >0.0975378</td>
#                         <td id="T_fe0e3758_3b47_11e9_8116_853153767eb5row2_col5" class="data row2 col5" >1.31559</td>
#             </tr>
#             <tr>
#                         <th id="T_fe0e3758_3b47_11e9_8116_853153767eb5level0_row3" class="row_heading level0 row3" >Fully Implicit Null, en ligne (batch)</th>
#                         <td id="T_fe0e3758_3b47_11e9_8116_853153767eb5row3_col0" class="data row3 col0" >973.075</td>
#                         <td id="T_fe0e3758_3b47_11e9_8116_853153767eb5row3_col1" class="data row3 col1" >72.8031</td>
#                         <td id="T_fe0e3758_3b47_11e9_8116_853153767eb5row3_col2" class="data row3 col2" >185.494</td>
#                         <td id="T_fe0e3758_3b47_11e9_8116_853153767eb5row3_col3" class="data row3 col3" >0.332</td>
#                         <td id="T_fe0e3758_3b47_11e9_8116_853153767eb5row3_col4" class="data row3 col4" >0.191356</td>
#                         <td id="T_fe0e3758_3b47_11e9_8116_853153767eb5row3_col5" class="data row3 col5" >2.54226</td>
#             </tr>
#             <tr>
#                         <th id="T_fe0e3758_3b47_11e9_8116_853153767eb5level0_row4" class="row_heading level0 row4" >Fully Implicit Null special, hors ligne</th>
#                         <td id="T_fe0e3758_3b47_11e9_8116_853153767eb5row4_col0" class="data row4 col0" >972.552</td>
#                         <td id="T_fe0e3758_3b47_11e9_8116_853153767eb5row4_col1" class="data row4 col1" >68.9297</td>
#                         <td id="T_fe0e3758_3b47_11e9_8116_853153767eb5row4_col2" class="data row4 col2" >160.791</td>
#                         <td id="T_fe0e3758_3b47_11e9_8116_853153767eb5row4_col3" class="data row4 col3" >0.327</td>
#                         <td id="T_fe0e3758_3b47_11e9_8116_853153767eb5row4_col4" class="data row4 col4" >0.164711</td>
#                         <td id="T_fe0e3758_3b47_11e9_8116_853153767eb5row4_col5" class="data row4 col5" >2.31613</td>
#             </tr>
#             <tr>
#                         <th id="T_fe0e3758_3b47_11e9_8116_853153767eb5level0_row5" class="row_heading level0 row5" >Simple, en ligne</th>
#                         <td id="T_fe0e3758_3b47_11e9_8116_853153767eb5row5_col0" class="data row5 col0

# %% [markdown]
# ### Classement par average reward normalisée (max)

# %%
col = 'average_reward_normalized_max' 
aggregat.sort_values(col, ascending=False)\
    .style.apply((lambda x: ['background: lightgreen' if x.name == col else '' for _ in x]))
# Out:
# <style  type="text/css" >
#     #T_fe16a9ec_3b47_11e9_8116_853153767eb5row0_col4 {
#             background:  lightgreen;
#         }    #T_fe16a9ec_3b47_11e9_8116_853153767eb5row1_col4 {
#             background:  lightgreen;
#         }    #T_fe16a9ec_3b47_11e9_8116_853153767eb5row2_col4 {
#             background:  lightgreen;
#         }    #T_fe16a9ec_3b47_11e9_8116_853153767eb5row3_col4 {
#             background:  lightgreen;
#         }    #T_fe16a9ec_3b47_11e9_8116_853153767eb5row4_col4 {
#             background:  lightgreen;
#         }    #T_fe16a9ec_3b47_11e9_8116_853153767eb5row5_col4 {
#             background:  lightgreen;
#         }    #T_fe16a9ec_3b47_11e9_8116_853153767eb5row6_col4 {
#             background:  lightgreen;
#         }    #T_fe16a9ec_3b47_11e9_8116_853153767eb5row7_col4 {
#             background:  lightgreen;
#         }    #T_fe16a9ec_3b47_11e9_8116_853153767eb5row8_col4 {
#             background:  lightgreen;
#         }    #T_fe16a9ec_3b47_11e9_8116_853153767eb5row9_col4 {
#             background:  lightgreen;
#         }    #T_fe16a9ec_3b47_11e9_8116_853153767eb5row10_col4 {
#             background:  lightgreen;
#         }    #T_fe16a9ec_3b47_11e9_8116_853153767eb5row11_col4 {
#             background:  lightgreen;
#         }    #T_fe16a9ec_3b47_11e9_8116_853153767eb5row12_col4 {
#             background:  lightgreen;
#         }    #T_fe16a9ec_3b47_11e9_8116_853153767eb5row13_col4 {
#             background:  lightgreen;
#         }    #T_fe16a9ec_3b47_11e9_8116_853153767eb5row14_col4 {
#             background:  lightgreen;
#         }    #T_fe16a9ec_3b47_11e9_8116_853153767eb5row15_col4 {
#             background:  lightgreen;
#         }    #T_fe16a9ec_3b47_11e9_8116_853153767eb5row16_col4 {
#             background:  lightgreen;
#         }    #T_fe16a9ec_3b47_11e9_8116_853153767eb5row17_col4 {
#             background:  lightgreen;
#         }    #T_fe16a9ec_3b47_11e9_8116_853153767eb5row18_col4 {
#             background:  lightgreen;
#         }    #T_fe16a9ec_3b47_11e9_8116_853153767eb5row19_col4 {
#             background:  lightgreen;
#         }    #T_fe16a9ec_3b47_11e9_8116_853153767eb5row20_col4 {
#             background:  lightgreen;
#         }    #T_fe16a9ec_3b47_11e9_8116_853153767eb5row21_col4 {
#             background:  lightgreen;
#         }    #T_fe16a9ec_3b47_11e9_8116_853153767eb5row22_col4 {
#             background:  lightgreen;
#         }    #T_fe16a9ec_3b47_11e9_8116_853153767eb5row23_col4 {
#             background:  lightgreen;
#         }</style><table id="T_fe16a9ec_3b47_11e9_8116_853153767eb5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >max_price</th>        <th class="col_heading level0 col1" >mean_price</th>        <th class="col_heading level0 col2" >average_reward</th>        <th class="col_heading level0 col3" >good_reco_ratio</th>        <th class="col_heading level0 col4" >average_reward_normalized_max</th>        <th class="col_heading level0 col5" >average_reward_normalized_mean</th>    </tr>    <tr>        <th class="index_name level0" >recommendation</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fe16a9ec_3b47_11e9_8116_853153767eb5level0_row0" class="row_heading level0 row0" >Null special, hors ligne</th>
#                         <td id="T_fe16a9ec_3b47_11e9_8116_853153767eb5row0_col0" class="data row0 col0" >975.428</td>
#                         <td id="T_fe16a9ec_3b47_11e9_8116_853153767eb5row0_col1" class="data row0 col1" >73.6725</td>
#                         <td id="T_fe16a9ec_3b47_11e9_8116_853153767eb5row0_col2" class="data row0 col2" >225.046</td>
#                         <td id="T_fe16a9ec_3b47_11e9_8116_853153767eb5row0_col3" class="data row0 col3" >0.307</td>
#                         <td id="T_fe16a9ec_3b47_11e9_8116_853153767eb5row0_col4" class="data row0 col4" >0.231238</td>
#                         <td id="T_fe16a9ec_3b47_11e9_8116_853153767eb5row0_col5" class="data row0 col5" >3.07212</td>
#             </tr>
#             <tr>
#                         <th id="T_fe16a9ec_3b47_11e9_8116_853153767eb5level0_row1" class="row_heading level0 row1" >Null special, en ligne</th>
#                         <td id="T_fe16a9ec_3b47_11e9_8116_853153767eb5row1_col0" class="data row1 col0" >971.067</td>
#                         <td id="T_fe16a9ec_3b47_11e9_8116_853153767eb5row1_col1" class="data row1 col1" >74.0511</td>
#                         <td id="T_fe16a9ec_3b47_11e9_8116_853153767eb5row1_col2" class="data row1 col2" >222.889</td>
#                         <td id="T_fe16a9ec_3b47_11e9_8116_853153767eb5row1_col3" class="data row1 col3" >0.308</td>
#                         <td id="T_fe16a9ec_3b47_11e9_8116_853153767eb5row1_col4" class="data row1 col4" >0.227899</td>
#                         <td id="T_fe16a9ec_3b47_11e9_8116_853153767eb5row1_col5" class="data row1 col5" >3.00142</td>
#             </tr>
#             <tr>
#                         <th id="T_fe16a9ec_3b47_11e9_8116_853153767eb5level0_row2" class="row_heading level0 row2" >Null, en ligne</th>
#                         <td id="T_fe16a9ec_3b47_11e9_8116_853153767eb5row2_col0" class="data row2 col0" >952.328</td>
#                         <td id="T_fe16a9ec_3b47_11e9_8116_853153767eb5row2_col1" class="data row2 col1" >69.9315</td>
#                         <td id="T_fe16a9ec_3b47_11e9_8116_853153767eb5row2_col2" class="data row2 col2" >195.544</td>
#                         <td id="T_fe16a9ec_3b47_11e9_8116_853153767eb5row2_col3" class="data row2 col3" >0.338</td>
#                         <td id="T_fe16a9ec_3b47_11e9_8116_853153767eb5row2_col4" class="data row2 col4" >0.204616</td>
#                         <td id="T_fe16a9ec_3b47_11e9_8116_853153767eb5row2_col5" class="data row2 col5" >2.77229</td>
#             </tr>
#             <tr>
#                         <th id="T_fe16a9ec_3b47_11e9_8116_853153767eb5level0_row3" class="row_heading level0 row3" >Fully Implicit Null binaire, en ligne (batch)</th>
#                         <td id="T_fe16a9ec_3b47_11e9_8116_853153767eb5row3_col0" class="data row3 col0" >972.192</td>
#                         <td id="T_fe16a9ec_3b47_11e9_8116_853153767eb5row3_col1" class="data row3 col1" >73.7033</td>
#                         <td id="T_fe16a9ec_3b47_11e9_8116_853153767eb5row3_col2" class="data row3 col2" >198.677</td>
#                         <td id="T_fe16a9ec_3b47_11e9_8116_853153767eb5row3_col3" class="data row3 col3" >0.321</td>
#                         <td id="T_fe16a9ec_3b47_11e9_8116_853153767eb5row3_col4" class="data row3 col4" >0.204053</td>
#                         <td id="T_fe16a9ec_3b47_11e9_8116_853153767eb5row3_col5" class="data row3 col5" >2.71585</td>
#             </tr>
#             <tr>
#                         <th id="T_fe16a9ec_3b47_11e9_8116_853153767eb5level0_row4" class="row_heading level0 row4" >Null special, en ligne (batch)</th>
#                         <td id="T_fe16a9ec_3b47_11e9_8116_853153767eb5row4_col0" class="data row4 col0" >973.635</td>
#                         <td id="T_fe16a9ec_3b47_11e9_8116_853153767eb5row4_col1" class="data row4 col1" >71.7754</td>
#                         <td id="T_fe16a9ec_3b47_11e9_8116_853153767eb5row4_col2" class="data row4 col2" >197.443</td>
#                         <td id="T_fe16a9ec_3b47_11e9_8116_853153767eb5row4_col3" class="data row4 col3" >0.303</td>
#                         <td id="T_fe16a9ec_3b47_11e9_8116_853153767eb5row4_col4" class="data row4 col4" >0.203496</td>
#                         <td id="T_fe16a9ec_3b47_11e9_8116_853153767eb5row4_col5" class="data row4 col5" >2.76737</td>
#             </tr>
#             <tr>
#                         <th id="T_fe16a9ec_3b47_11e9_8116_853153767eb5level0_row5" class="row_heading level0 row5" >Null, en ligne (batch)</th>
#                         <td id="T_fe16a9ec_3b47_11e9_8116_853153767eb5row5_col0" class="data row5 col0"

# %% [markdown]
# ### Classement par average reward normalisée (mean)

# %%
col = 'average_reward_normalized_mean' 
aggregat.sort_values(col, ascending=False)\
    .style.apply((lambda x: ['background: lightgreen' if x.name == col else '' for _ in x]))
# Out:
# <style  type="text/css" >
#     #T_39366b74_3b49_11e9_8116_853153767eb5row0_col5 {
#             background:  lightgreen;
#         }    #T_39366b74_3b49_11e9_8116_853153767eb5row1_col5 {
#             background:  lightgreen;
#         }    #T_39366b74_3b49_11e9_8116_853153767eb5row2_col5 {
#             background:  lightgreen;
#         }    #T_39366b74_3b49_11e9_8116_853153767eb5row3_col5 {
#             background:  lightgreen;
#         }    #T_39366b74_3b49_11e9_8116_853153767eb5row4_col5 {
#             background:  lightgreen;
#         }    #T_39366b74_3b49_11e9_8116_853153767eb5row5_col5 {
#             background:  lightgreen;
#         }    #T_39366b74_3b49_11e9_8116_853153767eb5row6_col5 {
#             background:  lightgreen;
#         }    #T_39366b74_3b49_11e9_8116_853153767eb5row7_col5 {
#             background:  lightgreen;
#         }    #T_39366b74_3b49_11e9_8116_853153767eb5row8_col5 {
#             background:  lightgreen;
#         }    #T_39366b74_3b49_11e9_8116_853153767eb5row9_col5 {
#             background:  lightgreen;
#         }    #T_39366b74_3b49_11e9_8116_853153767eb5row10_col5 {
#             background:  lightgreen;
#         }    #T_39366b74_3b49_11e9_8116_853153767eb5row11_col5 {
#             background:  lightgreen;
#         }    #T_39366b74_3b49_11e9_8116_853153767eb5row12_col5 {
#             background:  lightgreen;
#         }    #T_39366b74_3b49_11e9_8116_853153767eb5row13_col5 {
#             background:  lightgreen;
#         }    #T_39366b74_3b49_11e9_8116_853153767eb5row14_col5 {
#             background:  lightgreen;
#         }    #T_39366b74_3b49_11e9_8116_853153767eb5row15_col5 {
#             background:  lightgreen;
#         }    #T_39366b74_3b49_11e9_8116_853153767eb5row16_col5 {
#             background:  lightgreen;
#         }    #T_39366b74_3b49_11e9_8116_853153767eb5row17_col5 {
#             background:  lightgreen;
#         }    #T_39366b74_3b49_11e9_8116_853153767eb5row18_col5 {
#             background:  lightgreen;
#         }    #T_39366b74_3b49_11e9_8116_853153767eb5row19_col5 {
#             background:  lightgreen;
#         }    #T_39366b74_3b49_11e9_8116_853153767eb5row20_col5 {
#             background:  lightgreen;
#         }    #T_39366b74_3b49_11e9_8116_853153767eb5row21_col5 {
#             background:  lightgreen;
#         }    #T_39366b74_3b49_11e9_8116_853153767eb5row22_col5 {
#             background:  lightgreen;
#         }    #T_39366b74_3b49_11e9_8116_853153767eb5row23_col5 {
#             background:  lightgreen;
#         }</style><table id="T_39366b74_3b49_11e9_8116_853153767eb5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >max_price</th>        <th class="col_heading level0 col1" >mean_price</th>        <th class="col_heading level0 col2" >average_reward</th>        <th class="col_heading level0 col3" >good_reco_ratio</th>        <th class="col_heading level0 col4" >average_reward_normalized_max</th>        <th class="col_heading level0 col5" >average_reward_normalized_mean</th>    </tr>    <tr>        <th class="index_name level0" >recommendation</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_39366b74_3b49_11e9_8116_853153767eb5level0_row0" class="row_heading level0 row0" >Null special, hors ligne</th>
#                         <td id="T_39366b74_3b49_11e9_8116_853153767eb5row0_col0" class="data row0 col0" >975.428</td>
#                         <td id="T_39366b74_3b49_11e9_8116_853153767eb5row0_col1" class="data row0 col1" >73.6725</td>
#                         <td id="T_39366b74_3b49_11e9_8116_853153767eb5row0_col2" class="data row0 col2" >225.046</td>
#                         <td id="T_39366b74_3b49_11e9_8116_853153767eb5row0_col3" class="data row0 col3" >0.307</td>
#                         <td id="T_39366b74_3b49_11e9_8116_853153767eb5row0_col4" class="data row0 col4" >0.231238</td>
#                         <td id="T_39366b74_3b49_11e9_8116_853153767eb5row0_col5" class="data row0 col5" >3.07212</td>
#             </tr>
#             <tr>
#                         <th id="T_39366b74_3b49_11e9_8116_853153767eb5level0_row1" class="row_heading level0 row1" >Null special, en ligne</th>
#                         <td id="T_39366b74_3b49_11e9_8116_853153767eb5row1_col0" class="data row1 col0" >971.067</td>
#                         <td id="T_39366b74_3b49_11e9_8116_853153767eb5row1_col1" class="data row1 col1" >74.0511</td>
#                         <td id="T_39366b74_3b49_11e9_8116_853153767eb5row1_col2" class="data row1 col2" >222.889</td>
#                         <td id="T_39366b74_3b49_11e9_8116_853153767eb5row1_col3" class="data row1 col3" >0.308</td>
#                         <td id="T_39366b74_3b49_11e9_8116_853153767eb5row1_col4" class="data row1 col4" >0.227899</td>
#                         <td id="T_39366b74_3b49_11e9_8116_853153767eb5row1_col5" class="data row1 col5" >3.00142</td>
#             </tr>
#             <tr>
#                         <th id="T_39366b74_3b49_11e9_8116_853153767eb5level0_row2" class="row_heading level0 row2" >Null, hors ligne</th>
#                         <td id="T_39366b74_3b49_11e9_8116_853153767eb5row2_col0" class="data row2 col0" >969.804</td>
#                         <td id="T_39366b74_3b49_11e9_8116_853153767eb5row2_col1" class="data row2 col1" >67.71</td>
#                         <td id="T_39366b74_3b49_11e9_8116_853153767eb5row2_col2" class="data row2 col2" >191.386</td>
#                         <td id="T_39366b74_3b49_11e9_8116_853153767eb5row2_col3" class="data row2 col3" >0.315</td>
#                         <td id="T_39366b74_3b49_11e9_8116_853153767eb5row2_col4" class="data row2 col4" >0.196939</td>
#                         <td id="T_39366b74_3b49_11e9_8116_853153767eb5row2_col5" class="data row2 col5" >2.847</td>
#             </tr>
#             <tr>
#                         <th id="T_39366b74_3b49_11e9_8116_853153767eb5level0_row3" class="row_heading level0 row3" >Null, en ligne</th>
#                         <td id="T_39366b74_3b49_11e9_8116_853153767eb5row3_col0" class="data row3 col0" >952.328</td>
#                         <td id="T_39366b74_3b49_11e9_8116_853153767eb5row3_col1" class="data row3 col1" >69.9315</td>
#                         <td id="T_39366b74_3b49_11e9_8116_853153767eb5row3_col2" class="data row3 col2" >195.544</td>
#                         <td id="T_39366b74_3b49_11e9_8116_853153767eb5row3_col3" class="data row3 col3" >0.338</td>
#                         <td id="T_39366b74_3b49_11e9_8116_853153767eb5row3_col4" class="data row3 col4" >0.204616</td>
#                         <td id="T_39366b74_3b49_11e9_8116_853153767eb5row3_col5" class="data row3 col5" >2.77229</td>
#             </tr>
#             <tr>
#                         <th id="T_39366b74_3b49_11e9_8116_853153767eb5level0_row4" class="row_heading level0 row4" >Null special, en ligne (batch)</th>
#                         <td id="T_39366b74_3b49_11e9_8116_853153767eb5row4_col0" class="data row4 col0" >973.635</td>
#                         <td id="T_39366b74_3b49_11e9_8116_853153767eb5row4_col1" class="data row4 col1" >71.7754</td>
#                         <td id="T_39366b74_3b49_11e9_8116_853153767eb5row4_col2" class="data row4 col2" >197.443</td>
#                         <td id="T_39366b74_3b49_11e9_8116_853153767eb5row4_col3" class="data row4 col3" >0.303</td>
#                         <td id="T_39366b74_3b49_11e9_8116_853153767eb5row4_col4" class="data row4 col4" >0.203496</td>
#                         <td id="T_39366b74_3b49_11e9_8116_853153767eb5row4_col5" class="data row4 col5" >2.76737</td>
#             </tr>
#             <tr>
#                         <th id="T_39366b74_3b49_11e9_8116_853153767eb5level0_row5" class="row_heading level0 row5" >Null binaire, hors ligne</th>
#                         <td id="T_39366b74_3b49_11e9_8116_853153767eb5row5_col0" class="data row5 col0" >958.894</td>

# %% [markdown]
# ### Résumé (classé par average_reward)

# %%
cm = sns.light_palette("green", as_cmap=True)
col = 'average_reward' 
aggregat.sort_values(col, ascending=False)\
    .style.background_gradient(cmap=cm).highlight_max(color='red')
# Out:
# <style  type="text/css" >
#     #T_21cefcda_3b49_11e9_8116_853153767eb5row0_col0 {
#             background-color:  #319b31;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row0_col1 {
#             background-color:  #2c982c;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row0_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             background-color:  red;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row0_col3 {
#             background-color:  #7bc47b;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row0_col4 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             background-color:  red;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row0_col5 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             background-color:  red;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row1_col0 {
#             background-color:  #50ac50;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row1_col1 {
#             background-color:  #209220;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row1_col2 {
#             background-color:  #048204;
#             color:  #f1f1f1;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row1_col3 {
#             background-color:  #78c278;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row1_col4 {
#             background-color:  #058305;
#             color:  #f1f1f1;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row1_col5 {
#             background-color:  #098509;
#             color:  #f1f1f1;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row2_col0 {
#             background-color:  #48a848;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row2_col1 {
#             background-color:  #2b982b;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row2_col2 {
#             background-color:  #2f9a2f;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row2_col3 {
#             background-color:  #4aa94a;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row2_col4 {
#             background-color:  #2f9a2f;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row2_col5 {
#             background-color:  #2e992e;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row3_col0 {
#             background-color:  #3ea23e;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row3_col1 {
#             background-color:  #66b866;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row3_col2 {
#             background-color:  #319b31;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row3_col3 {
#             background-color:  #8acc8a;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row3_col4 {
#             background-color:  #309a30;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row3_col5 {
#             background-color:  #289628;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row4_col0 {
#             background-color:  #d4f6d4;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row4_col1 {
#             background-color:  #9ed79e;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row4_col2 {
#             background-color:  #349d34;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row4_col3 {
#             background-color:  #0e870e;
#             color:  #f1f1f1;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row4_col4 {
#             background-color:  #2d992d;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row4_col5 {
#             background-color:  #279527;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row5_col0 {
#             background-color:  #1f911f;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row5_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             background-color:  red;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row5_col2 {
#             background-color:  #359d35;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row5_col3 {
#             background-color:  #58b158;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row5_col4 {
#             background-color:  #379e37;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row5_col5 {
#             background-color:  #3aa03a;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row6_col0 {
#             background-color:  #7ac47a;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row6_col1 {
#             background-color:  #4caa4c;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row6_col2 {
#             background-color:  #3aa03a;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row6_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             background-color:  red;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row6_col4 {
#             background-color:  #379e37;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row6_col5 {
#             background-color:  #359d35;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row7_col0 {
#             background-color:  #59b159;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row7_col1 {
#             background-color:  #e1fde1;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row7_col2 {
#             background-color:  #3ba13b;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row7_col3 {
#             background-color:  #5fb55f;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row7_col4 {
#             background-color:  #3aa03a;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row7_col5 {
#             background-color:  #1d901d;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row8_col0 {
#             background-color:  #a6dca6;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row8_col1 {
#             background-color:  #bee9be;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row8_col2 {
#             background-color:  #44a544;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row8_col3 {
#             background-color:  #a6dca6;
#             color:  #000000;
#             : ;
#         }    #T_21cefcda_3b49_11e9_8116_853153767eb5row8_col4 {
#             background-color:  #3aa03a;
#             color:  #000000;

# %% [markdown]
# La recommendation prenant en charge les nulls semble meilleure. <br>
#   1) Null secial en ligne (batch) <br>
#   2) Fully Implicit Null special, en ligne (batch) <br>
#   3) Null, hors ligne <br>
