# %% [markdown]
# # Recommandation avec cold start

# %%
import pandas as pd

import seaborn as sns

from deep_implicit_feedback_recsys import *

from cold_star_recommender import *

from recommender_evaluation import *
# Out:
# Using TensorFlow backend.

# %%
def normalized_results(df, recommender_type):
    df['average_reward_normalized_max'] = df['average_reward'] / df['max_price']
    df['average_reward_normalized_mean'] = df['average_reward'] / df['mean_price']
    df['recommendation'] = recommender_type
    return df

# %%
n_loop = 10
n_pred = 100
online_batch_size = n_pred // 10

user_dim = item_dim = 8
n_hidden = 1
hidden_size = 21
dropout = 0.1
l2_reg = 0

# %% [markdown]
# ## Mesures d'échantillon

# %% [markdown]
# ### Implicit Recommender Simple, hors ligne

# %%
# %%time
ImplicitRecommenderSimple_df = eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartImplicitRecommender,
                                                                      ImplicitRecommenderClass=ImplicitRecommenderSimple, 
                                                                      n_loop=n_loop, n_pred=n_pred,
                                                                      user_dim=user_dim, item_dim=item_dim,
                                                                      n_hidden=n_hidden, hidden_size=hidden_size, 
                                                                      dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 20.9 s, sys: 334 ms, total: 21.2 s
# Wall time: 31.4 s

# %%
ImplicitRecommenderSimple_df_normalized = normalized_results(ImplicitRecommenderSimple_df, 'Simple, hors ligne')
ImplicitRecommenderSimple_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  997.879012   88.299242      265.191577             0.30
# 1  947.862314   67.686231      185.399791             0.28
# 2  948.972033   75.761556      115.545688             0.26
# 3  998.324132   64.455425      139.341133             0.39
# 4  990.345768   76.283732      126.158248             0.27
# 5  940.443322   73.004984      234.485492             0.34
# 6  943.565087   61.075670       56.241251             0.33
# 7  965.387519   76.172219      202.781990             0.28
# 8  938.581672   82.970529      167.217213             0.41
# 9  938.365176   71.419168      119.235717             0.29
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.265755                        3.003328
# 1                       0.195598                        2.739106
# 2                       0.121759                        1.525123
# 3                       0.139575                        2.161822
# 4                       0.127388                        1.653803
# 5                       0.249335                        3.211911
# 6                       0.059605                        0.920845
# 7                       0.210052                        2.662152
# 8                       0.178159                        2.015381
# 9                       0.127068                        1.669520
#
#        recommendation
# 0  Simple, hors ligne
# 1  Simple, hors ligne
# 2  Simple, hors ligne
# 3  Simple, hors ligne
# 4  Simple, hors ligne
# 5  Simple, hors ligne
# 6  Simple, hors ligne
# 7  Simple, hors ligne
# 8  Simple, hors ligne
# 9  Simple, hors ligne

# %% [markdown]
# ### Implicit Recommender Simple, en ligne

# %%
# %%time
ImplicitRecommenderSimple_online_df = eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartImplicitRecommender,
                                                                             ImplicitRecommenderClass=ImplicitRecommenderSimple,
                                                                             n_loop=n_loop, n_pred=n_pred,
                                                                             online_batch_size=1,
                                                                             user_dim=user_dim, item_dim=item_dim,
                                                                             n_hidden=n_hidden, hidden_size=hidden_size, 
                                                                             dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 26.9 s, sys: 350 ms, total: 27.3 s
# Wall time: 36.9 s

# %%
ImplicitRecommenderSimple_online_df_normalized = normalized_results(ImplicitRecommenderSimple_online_df, 'Simple, en ligne')
ImplicitRecommenderSimple_online_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  952.012930   77.678219       80.753952             0.31
# 1  969.382084   72.002127      263.571668             0.38
# 2  969.611185   83.246931      131.793188             0.37
# 3  998.290434   69.679958       66.144422             0.31
# 4  955.620244   67.575366      119.235415             0.23
# 5  936.223720   74.178467       77.449684             0.39
# 6  923.016948   67.498679       88.342572             0.28
# 7  918.774724   69.227933      109.266266             0.37
# 8  994.593906   81.313298       96.859633             0.25
# 9  991.579469   67.858041       98.396622             0.17
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.084824                        1.039596
# 1                       0.271897                        3.660609
# 2                       0.135924                        1.583160
# 3                       0.066258                        0.949260
# 4                       0.124773                        1.764480
# 5                       0.082726                        1.044099
# 6                       0.095711                        1.308804
# 7                       0.118926                        1.578355
# 8                       0.097386                        1.191191
# 9                       0.099232                        1.450036
#
#      recommendation
# 0  Simple, en ligne
# 1  Simple, en ligne
# 2  Simple, en ligne
# 3  Simple, en ligne
# 4  Simple, en ligne
# 5  Simple, en ligne
# 6  Simple, en ligne
# 7  Simple, en ligne
# 8  Simple, en ligne
# 9  Simple, en ligne

# %% [markdown]
# ### Implicit Recommender Simple, en ligne version batch

# %%
# %%time
ImplicitRecommenderSimple_online_batch_df = eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartImplicitRecommender,
                                                                             ImplicitRecommenderClass=ImplicitRecommenderSimple,
                                                                             n_loop=n_loop, n_pred=n_pred,
                                                                             user_dim=user_dim, item_dim=item_dim,
                                                                             online_batch_size=online_batch_size,
                                                                             n_hidden=n_hidden, hidden_size=hidden_size, 
                                                                             dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 33.1 s, sys: 427 ms, total: 33.5 s
# Wall time: 43.8 s

# %%
ImplicitRecommenderSimple_online_batch_df_normalized = normalized_results(ImplicitRecommenderSimple_online_batch_df, 'Simple, en ligne (batch)')
ImplicitRecommenderSimple_online_batch_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  943.884295   85.184365       70.957704             0.39
# 1  973.869896   71.565894       98.488133             0.28
# 2  953.604228   61.365755      168.638632             0.25
# 3  977.174327   73.596402      249.107613             0.29
# 4  975.787589   63.198873      103.605272             0.23
# 5  999.038031   71.204735      214.911138             0.27
# 6  981.434632   55.259042      228.370554             0.28
# 7  961.310025   55.224734      199.755957             0.28
# 8  967.042462   58.688880      208.262556             0.29
# 9  945.314939   59.778189      263.888057             0.32
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.075176                        0.832990
# 1                       0.101131                        1.376188
# 2                       0.176843                        2.748090
# 3                       0.254926                        3.384780
# 4                       0.106176                        1.639353
# 5                       0.215118                        3.018214
# 6                       0.232691                        4.132727
# 7                       0.207796                        3.617147
# 8                       0.215360                        3.548586
# 9                       0.279154                        4.414454
#
#              recommendation
# 0  Simple, en ligne (batch)
# 1  Simple, en ligne (batch)
# 2  Simple, en ligne (batch)
# 3  Simple, en ligne (batch)
# 4  Simple, en ligne (batch)
# 5  Simple, en ligne (batch)
# 6  Simple, en ligne (batch)
# 7  Simple, en ligne (batch)
# 8  Simple, en ligne (batch)
# 9  Simple, en ligne (batch)

# %% [markdown]
# ### Implicit Recommender avec nuls sans indicateur, hors ligne

# %%
# %%time
ImplicitRecommenderWithNull_no_indicator_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull_no_indicator, 
                                           n_loop=n_loop, n_pred=n_pred,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 41.8 s, sys: 647 ms, total: 42.4 s
# Wall time: 53.4 s

# %%
ImplicitRecommenderWithNull_no_indicator_df_normalized = normalized_results(ImplicitRecommenderWithNull_no_indicator_df, 'Null, hors ligne')
ImplicitRecommenderWithNull_no_indicator_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  996.111724   83.976072       90.978837             0.43
# 1  946.678719   65.224312      167.947460             0.25
# 2  920.417880   61.378054      288.205929             0.39
# 3  984.515885   71.266746       76.653379             0.33
# 4  986.873752   63.721624      220.398174             0.27
# 5  952.897978   67.036386      200.301404             0.29
# 6  987.967053   67.297011       87.496933             0.14
# 7  989.399098   73.752646      173.838552             0.28
# 8  963.918082   74.495461      123.813266             0.32
# 9  952.376514   68.390891      246.927707             0.32
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.091334                        1.083390
# 1                       0.177407                        2.574921
# 2                       0.313125                        4.695586
# 3                       0.077859                        1.075584
# 4                       0.223330                        3.458766
# 5                       0.210202                        2.987950
# 6                       0.088563                        1.300161
# 7                       0.175701                        2.357048
# 8                       0.128448                        1.662024
# 9                       0.259275                        3.610535
#
#      recommendation
# 0  Null, hors ligne
# 1  Null, hors ligne
# 2  Null, hors ligne
# 3  Null, hors ligne
# 4  Null, hors ligne
# 5  Null, hors ligne
# 6  Null, hors ligne
# 7  Null, hors ligne
# 8  Null, hors ligne
# 9  Null, hors ligne

# %% [markdown]
# ### Implicit Recommender avec nuls sans indicateur, en ligne

# %%
# %%time
ImplicitRecommenderWithNull_no_indicator_online_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull_no_indicator,
                                           n_loop=n_loop, n_pred=n_pred,
                                           online_batch_size=1,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 47.6 s, sys: 703 ms, total: 48.3 s
# Wall time: 1min 8s

# %%
ImplicitRecommenderWithNull_no_indicator_online_df_normalized = normalized_results(ImplicitRecommenderWithNull_no_indicator_online_df,
                                                                                   'Null, en ligne')
ImplicitRecommenderWithNull_no_indicator_online_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  960.604510   64.778654       61.168898             0.21
# 1  993.459224   62.373148       98.961349             0.36
# 2  997.961582   68.469098      155.536440             0.40
# 3  897.703638   72.714470       96.548442             0.35
# 4  989.425729   66.592498      178.853442             0.25
# 5  975.257060   69.983924      128.192854             0.22
# 6  998.846373   67.573991       87.918923             0.24
# 7  986.394257   70.259388      226.022245             0.30
# 8  949.417018   67.384113       80.208380             0.34
# 9  975.678881   72.376128       67.265602             0.21
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.063678                        0.944276
# 1                       0.099613                        1.586602
# 2                       0.155854                        2.271630
# 3                       0.107550                        1.327775
# 4                       0.180765                        2.685790
# 5                       0.131445                        1.831747
# 6                       0.088020                        1.301076
# 7                       0.229140                        3.216969
# 8                       0.084482                        1.190316
# 9                       0.068942                        0.929389
#
#    recommendation
# 0  Null, en ligne
# 1  Null, en ligne
# 2  Null, en ligne
# 3  Null, en ligne
# 4  Null, en ligne
# 5  Null, en ligne
# 6  Null, en ligne
# 7  Null, en ligne
# 8  Null, en ligne
# 9  Null, en ligne

# %% [markdown]
# ### Implicit Recommender avec nuls sans indicateur, en ligne version batch

# %%
# %%time
ImplicitRecommenderWithNull_no_indicator_online_batch_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull_no_indicator,
                                           n_loop=n_loop, n_pred=n_pred,
                                           online_batch_size=online_batch_size,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 54.6 s, sys: 708 ms, total: 55.4 s
# Wall time: 1min 5s

# %%
ImplicitRecommenderWithNull_no_indicator_online_batch_df_normalized = \
    normalized_results(ImplicitRecommenderWithNull_no_indicator_online_batch_df, 'Null, en ligne (batch)')
ImplicitRecommenderWithNull_no_indicator_online_batch_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  954.110456   66.801363       67.572129             0.33
# 1  980.131124   64.664252      274.554147             0.35
# 2  952.860608   71.393357      131.677805             0.29
# 3  932.529756   67.106206       79.098282             0.38
# 4  937.310586   66.387621      119.689423             0.29
# 5  938.462315   65.158408      241.672614             0.36
# 6  982.326308   63.438114      179.586785             0.38
# 7  977.262092   82.131624      125.298100             0.29
# 8  975.986931   75.637342      253.603096             0.30
# 9  990.723712   75.884859      214.826821             0.27
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.070822                        1.011538
# 1                       0.280120                        4.245841
# 2                       0.138192                        1.844399
# 3                       0.084821                        1.178703
# 4                       0.127695                        1.802888
# 5                       0.257520                        3.709001
# 6                       0.182818                        2.830897
# 7                       0.128213                        1.525577
# 8                       0.259843                        3.352882
# 9                       0.216838                        2.830958
#
#            recommendation
# 0  Null, en ligne (batch)
# 1  Null, en ligne (batch)
# 2  Null, en ligne (batch)
# 3  Null, en ligne (batch)
# 4  Null, en ligne (batch)
# 5  Null, en ligne (batch)
# 6  Null, en ligne (batch)
# 7  Null, en ligne (batch)
# 8  Null, en ligne (batch)
# 9  Null, en ligne (batch)

# %% [markdown]
# ### Implicit Recommender avec nuls et indicateur binaire, hors ligne

# %%
# %%time
ImplicitRecommenderWithNull_binary_indicator_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull_binary_indicator,
                                           n_loop=n_loop, n_pred=n_pred,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 1min 1s, sys: 716 ms, total: 1min 2s
# Wall time: 1min 17s

# %%
ImplicitRecommenderWithNull_binary_indicator_df_normalized = normalized_results(ImplicitRecommenderWithNull_binary_indicator_df,
                                                                                'Null binaire, hors ligne')
ImplicitRecommenderWithNull_binary_indicator_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  989.336813   70.481330      134.731937             0.32
# 1  995.820879   86.373032      305.080902             0.35
# 2  984.820663   64.817872      248.089093             0.33
# 3  907.528209   47.042537       73.626076             0.23
# 4  878.213995   63.511606       62.846700             0.25
# 5  922.150415   70.553725      100.314180             0.26
# 6  951.208354   68.871354       68.931229             0.29
# 7  998.666650   84.447176       54.225272             0.25
# 8  959.950556   72.697240      232.547360             0.29
# 9  905.129280   72.239251       97.618181             0.24
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.136184                        1.911598
# 1                       0.306361                        3.532131
# 2                       0.251913                        3.827480
# 3                       0.081128                        1.565096
# 4                       0.071562                        0.989531
# 5                       0.108783                        1.421813
# 6                       0.072467                        1.000869
# 7                       0.054298                        0.642121
# 8                       0.242249                        3.198847
# 9                       0.107850                        1.351318
#
#              recommendation
# 0  Null binaire, hors ligne
# 1  Null binaire, hors ligne
# 2  Null binaire, hors ligne
# 3  Null binaire, hors ligne
# 4  Null binaire, hors ligne
# 5  Null binaire, hors ligne
# 6  Null binaire, hors ligne
# 7  Null binaire, hors ligne
# 8  Null binaire, hors ligne
# 9  Null binaire, hors ligne

# %% [markdown]
# ### Implicit Recommender avec nuls et indicateur binaire, en ligne

# %%
# %%time
ImplicitRecommenderWithNull_binary_indicator_online_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull_binary_indicator,
                                           n_loop=n_loop, n_pred=n_pred,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 1min 4s, sys: 640 ms, total: 1min 5s
# Wall time: 1min 23s

# %%
ImplicitRecommenderWithNull_binary_indicator_online_df_normalized = normalized_results(ImplicitRecommenderWithNull_binary_indicator_online_df,
                                                                                       'Null binaire, en ligne')
ImplicitRecommenderWithNull_binary_indicator_online_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  975.756181   73.360654      201.729950             0.28
# 1  905.924075   61.358504       97.719219             0.27
# 2  984.547678   82.388316      124.276941             0.32
# 3  989.253631   70.727436       73.142978             0.32
# 4  980.032421   72.321866      234.714598             0.29
# 5  991.750232   69.257861      266.933407             0.34
# 6  999.516756   78.074533      314.918269             0.42
# 7  925.568375   63.157989       99.016557             0.25
# 8  958.061215   79.862930      166.040045             0.22
# 9  993.588182   70.628569       94.607963             0.28
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.206742                        2.749838
# 1                       0.107867                        1.592595
# 2                       0.126227                        1.508429
# 3                       0.073938                        1.034153
# 4                       0.239497                        3.245417
# 5                       0.269154                        3.854197
# 6                       0.315071                        4.033559
# 7                       0.106979                        1.567760
# 8                       0.173308                        2.079063
# 9                       0.095218                        1.339514
#
#            recommendation
# 0  Null binaire, en ligne
# 1  Null binaire, en ligne
# 2  Null binaire, en ligne
# 3  Null binaire, en ligne
# 4  Null binaire, en ligne
# 5  Null binaire, en ligne
# 6  Null binaire, en ligne
# 7  Null binaire, en ligne
# 8  Null binaire, en ligne
# 9  Null binaire, en ligne

# %% [markdown]
# ### Implicit Recommender avec nuls et indicateur binaire, en ligne version batch

# %%
# %%time
ImplicitRecommenderWithNull_binary_indicator_online_batch_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull_binary_indicator,
                                           n_loop=n_loop, n_pred=n_pred,
                                           online_batch_size=online_batch_size,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 1min 14s, sys: 758 ms, total: 1min 15s
# Wall time: 1min 24s

# %%
ImplicitRecommenderWithNull_binary_indicator_online_batch_df_normalized = \
    normalized_results(ImplicitRecommenderWithNull_binary_indicator_online_batch_df, 'Null binaire, en ligne (batch)')
ImplicitRecommenderWithNull_binary_indicator_online_batch_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  998.485053   79.116120      122.119369             0.38
# 1  924.671731   74.905442      235.672199             0.31
# 2  982.906215   75.747348      339.417607             0.39
# 3  997.593595   73.685087       58.659212             0.29
# 4  994.698825   66.944924      104.353186             0.26
# 5  921.710342   80.647820      132.755852             0.22
# 6  989.577971   68.615318      223.309155             0.28
# 7  995.816571   75.785992      290.654679             0.37
# 8  983.484106   69.087965      176.461676             0.33
# 9  967.749320   69.263475      124.050767             0.17
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.122305                        1.543546
# 1                       0.254871                        3.146263
# 2                       0.345320                        4.480917
# 3                       0.058801                        0.796080
# 4                       0.104909                        1.558792
# 5                       0.144032                        1.646118
# 6                       0.225661                        3.254509
# 7                       0.291876                        3.835203
# 8                       0.179425                        2.554159
# 9                       0.128185                        1.790998
#
#                    recommendation
# 0  Null binaire, en ligne (batch)
# 1  Null binaire, en ligne (batch)
# 2  Null binaire, en ligne (batch)
# 3  Null binaire, en ligne (batch)
# 4  Null binaire, en ligne (batch)
# 5  Null binaire, en ligne (batch)
# 6  Null binaire, en ligne (batch)
# 7  Null binaire, en ligne (batch)
# 8  Null binaire, en ligne (batch)
# 9  Null binaire, en ligne (batch)

# %% [markdown]
# ### Implicit Recommender avec nuls et indicateur special, hors ligne

# %%
# %%time
ImplicitRecommenderWithNull_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull,
                                           n_loop=n_loop, n_pred=n_pred,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 1min 19s, sys: 661 ms, total: 1min 19s
# Wall time: 1min 30s

# %%
ImplicitRecommenderWithNull_df_normalized = normalized_results(ImplicitRecommenderWithNull_df, 'Null special, hors ligne')
ImplicitRecommenderWithNull_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  984.942539   71.025990      203.122720             0.30
# 1  990.503123   64.659331      162.729007             0.24
# 2  874.727921   69.513800      282.148788             0.37
# 3  984.914045   78.707715      288.156931             0.36
# 4  927.076515   57.671730       80.683838             0.30
# 5  894.081928   51.385245      173.972739             0.28
# 6  969.487885   66.993749      226.539417             0.28
# 7  999.825178   78.188068      110.703842             0.38
# 8  973.461088   72.357618      111.778633             0.31
# 9  990.283219   73.920293      186.943697             0.49
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.206228                        2.859837
# 1                       0.164289                        2.516713
# 2                       0.322556                        4.058889
# 3                       0.292571                        3.661101
# 4                       0.087030                        1.399019
# 5                       0.194583                        3.385656
# 6                       0.233669                        3.381501
# 7                       0.110723                        1.415866
# 8                       0.114826                        1.544808
# 9                       0.188778                        2.528990
#
#              recommendation
# 0  Null special, hors ligne
# 1  Null special, hors ligne
# 2  Null special, hors ligne
# 3  Null special, hors ligne
# 4  Null special, hors ligne
# 5  Null special, hors ligne
# 6  Null special, hors ligne
# 7  Null special, hors ligne
# 8  Null special, hors ligne
# 9  Null special, hors ligne

# %% [markdown]
# ### Implicit Recommender avec nuls et indicateur special, en ligne

# %%
# %%time
ImplicitRecommenderWithNull_online_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull,
                                           n_loop=n_loop, n_pred=n_pred,
                                           online_batch_size=1,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 1min 28s, sys: 821 ms, total: 1min 29s
# Wall time: 1min 45s

# %%
ImplicitRecommenderWithNull_online_df_normalized = normalized_results(ImplicitRecommenderWithNull_online_df, 'Null special, en ligne')
ImplicitRecommenderWithNull_online_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  982.703075   64.026440      251.106161             0.29
# 1  972.064618   69.541125      143.005943             0.37
# 2  999.686253   71.534304      260.365142             0.30
# 3  970.301815   67.564507      255.823923             0.36
# 4  893.054030   75.871561       54.660367             0.20
# 5  984.854822   79.899395      452.560981             0.52
# 6  984.745295   66.730913      324.537482             0.39
# 7  939.344432   53.731649      169.461375             0.31
# 8  958.643447   74.998396      215.036097             0.28
# 9  953.678231   76.916620      182.665000             0.23
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.255526                        3.921914
# 1                       0.147116                        2.056423
# 2                       0.260447                        3.639724
# 3                       0.263654                        3.786366
# 4                       0.061206                        0.720433
# 5                       0.459521                        5.664135
# 6                       0.329565                        4.863375
# 7                       0.180404                        3.153847
# 8                       0.224313                        2.867209
# 9                       0.191537                        2.374844
#
#            recommendation
# 0  Null special, en ligne
# 1  Null special, en ligne
# 2  Null special, en ligne
# 3  Null special, en ligne
# 4  Null special, en ligne
# 5  Null special, en ligne
# 6  Null special, en ligne
# 7  Null special, en ligne
# 8  Null special, en ligne
# 9  Null special, en ligne

# %% [markdown]
# ### Implicit Recommender avec nuls et indicateur special, en ligne version batch

# %%
# %%time
ImplicitRecommenderWithNull_online_batch_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull,
                                           n_loop=n_loop, n_pred=n_pred,
                                           online_batch_size=online_batch_size,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 1min 34s, sys: 834 ms, total: 1min 34s
# Wall time: 1min 48s

# %%
ImplicitRecommenderWithNull_online_batch_df_normalized = \
    normalized_results(ImplicitRecommenderWithNull_online_batch_df, 'Null special, en ligne (batch)')
ImplicitRecommenderWithNull_online_batch_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  994.213406   75.011366      221.160497             0.32
# 1  920.747154   69.482213       91.210289             0.32
# 2  998.305594   85.717827       97.407993             0.22
# 3  993.112886   72.677808      149.650339             0.19
# 4  961.702780   72.053348      327.233551             0.43
# 5  994.062035   69.508587      126.670174             0.33
# 6  913.102987   65.935949      216.077819             0.30
# 7  965.698605   63.447653      225.862765             0.28
# 8  927.395373   78.231993      215.122834             0.28
# 9  951.160215   62.419089       58.918959             0.29
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.222448                        2.948360
# 1                       0.099061                        1.312714
# 2                       0.097573                        1.136380
# 3                       0.150688                        2.059093
# 4                       0.340265                        4.541545
# 5                       0.127427                        1.822367
# 6                       0.236641                        3.277087
# 7                       0.233885                        3.559829
# 8                       0.231965                        2.749806
# 9                       0.061944                        0.943925
#
#                    recommendation
# 0  Null special, en ligne (batch)
# 1  Null special, en ligne (batch)
# 2  Null special, en ligne (batch)
# 3  Null special, en ligne (batch)
# 4  Null special, en ligne (batch)
# 5  Null special, en ligne (batch)
# 6  Null special, en ligne (batch)
# 7  Null special, en ligne (batch)
# 8  Null special, en ligne (batch)
# 9  Null special, en ligne (batch)

# %% [markdown]
# ### Fully Implicit Recommender Simple, hors ligne

# %%
# %%time
FullyImplicitRecommenderSimple_df = eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartFullyImplicitRecommender,
                                                                      ImplicitRecommenderClass=ImplicitRecommenderSimple, 
                                                                      n_loop=n_loop, n_pred=n_pred,
                                                                      user_dim=user_dim, item_dim=item_dim,
                                                                      n_hidden=n_hidden, hidden_size=hidden_size, 
                                                                      dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 22.4 s, sys: 196 ms, total: 22.6 s
# Wall time: 35.9 s

# %%
FullyImplicitRecommenderSimple_df_normalized = normalized_results(FullyImplicitRecommenderSimple_df, 'Fully Implicit Simple, hors ligne')
FullyImplicitRecommenderSimple_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  893.617353   73.121931      118.227641             0.29
# 1  999.469283   64.789239      127.896386             0.25
# 2  977.670577   70.995891      170.347143             0.28
# 3  989.161236   57.109541      164.663079             0.32
# 4  938.824002   70.360608      199.396801             0.34
# 5  972.869893   76.149463      181.334581             0.28
# 6  993.347700   64.451982      120.208464             0.23
# 7  998.862154   70.426847      227.504248             0.32
# 8  965.450789   68.135622      204.772912             0.32
# 9  971.597488   64.311732      170.277299             0.33
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.132302                        1.616856
# 1                       0.127964                        1.974037
# 2                       0.174238                        2.399394
# 3                       0.166467                        2.883285
# 4                       0.212390                        2.833927
# 5                       0.186391                        2.381298
# 6                       0.121013                        1.865086
# 7                       0.227763                        3.230363
# 8                       0.212101                        3.005372
# 9                       0.175255                        2.647686
#
#                       recommendation
# 0  Fully Implicit Simple, hors ligne
# 1  Fully Implicit Simple, hors ligne
# 2  Fully Implicit Simple, hors ligne
# 3  Fully Implicit Simple, hors ligne
# 4  Fully Implicit Simple, hors ligne
# 5  Fully Implicit Simple, hors ligne
# 6  Fully Implicit Simple, hors ligne
# 7  Fully Implicit Simple, hors ligne
# 8  Fully Implicit Simple, hors ligne
# 9  Fully Implicit Simple, hors ligne

# %% [markdown]
# ### Fully Implicit Recommender Simple, en ligne

# %%
# %%time
FullyImplicitRecommenderSimple_online_df = eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartFullyImplicitRecommender,
                                                                             ImplicitRecommenderClass=ImplicitRecommenderSimple,
                                                                             n_loop=n_loop, n_pred=n_pred,
                                                                             online_batch_size=1,
                                                                             user_dim=user_dim, item_dim=item_dim,
                                                                             n_hidden=n_hidden, hidden_size=hidden_size, 
                                                                             dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 23.8 s, sys: 237 ms, total: 24.1 s
# Wall time: 34.5 s

# %%
FullyImplicitRecommenderSimple_online_df_normalized = normalized_results(FullyImplicitRecommenderSimple_online_df, 'Fully Implicit Simple, en ligne')
FullyImplicitRecommenderSimple_online_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  985.023303   72.804089      166.298107             0.28
# 1  983.583501   82.408262      219.641527             0.32
# 2  954.641555   59.280200      208.145970             0.39
# 3  947.950537   75.646933      228.617566             0.43
# 4  809.017280   65.831636       96.261141             0.28
# 5  950.347492   69.248131      154.550460             0.38
# 6  989.106070   63.334881      190.517160             0.30
# 7  975.878492   72.332274      226.881381             0.36
# 8  997.383735   69.973926      196.230696             0.32
# 9  902.974080   70.925075      176.774847             0.35
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.168827                        2.284186
# 1                       0.223307                        2.665285
# 2                       0.218036                        3.511222
# 3                       0.241170                        3.022166
# 4                       0.118985                        1.462232
# 5                       0.162625                        2.231836
# 6                       0.192615                        3.008092
# 7                       0.232489                        3.136655
# 8                       0.196745                        2.804340
# 9                       0.195770                        2.492417
#
#                     recommendation
# 0  Fully Implicit Simple, en ligne
# 1  Fully Implicit Simple, en ligne
# 2  Fully Implicit Simple, en ligne
# 3  Fully Implicit Simple, en ligne
# 4  Fully Implicit Simple, en ligne
# 5  Fully Implicit Simple, en ligne
# 6  Fully Implicit Simple, en ligne
# 7  Fully Implicit Simple, en ligne
# 8  Fully Implicit Simple, en ligne
# 9  Fully Implicit Simple, en ligne

# %% [markdown]
# ### Fully Implicit Recommender Simple, en ligne version batch

# %%
# %%time
FullyImplicitRecommenderSimple_online_batch_df = eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartFullyImplicitRecommender,
                                                                             ImplicitRecommenderClass=ImplicitRecommenderSimple,
                                                                             n_loop=n_loop, n_pred=n_pred,
                                                                             online_batch_size=online_batch_size,
                                                                             user_dim=user_dim, item_dim=item_dim,
                                                                             n_hidden=n_hidden, hidden_size=hidden_size, 
                                                                             dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 23.9 s, sys: 216 ms, total: 24.1 s
# Wall time: 35.9 s

# %%
FullyImplicitRecommenderSimple_online_batch_df_normalized = normalized_results(FullyImplicitRecommenderSimple_online_batch_df, 'Fully Implicit Simple, en ligne (batch)')
FullyImplicitRecommenderSimple_online_batch_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  964.877877   70.002752      247.630727             0.37
# 1  853.791203   74.161832      165.475208             0.29
# 2  937.271707   63.005581      166.765899             0.28
# 3  986.612112   65.616563      148.513185             0.30
# 4  940.568942   74.551377      185.596369             0.31
# 5  869.586883   64.861682      153.253592             0.33
# 6  988.065275   69.873146      206.572337             0.41
# 7  959.349456   68.454502      122.178912             0.22
# 8  905.531312   70.886880      218.047083             0.31
# 9  918.981269   65.419398      145.092653             0.26
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.256645                        3.537443
# 1                       0.193812                        2.231272
# 2                       0.177927                        2.646843
# 3                       0.150528                        2.263349
# 4                       0.197324                        2.489510
# 5                       0.176237                        2.362775
# 6                       0.209068                        2.956391
# 7                       0.127356                        1.784819
# 8                       0.240795                        3.075986
# 9                       0.157884                        2.217884
#
#                             recommendation
# 0  Fully Implicit Simple, en ligne (batch)
# 1  Fully Implicit Simple, en ligne (batch)
# 2  Fully Implicit Simple, en ligne (batch)
# 3  Fully Implicit Simple, en ligne (batch)
# 4  Fully Implicit Simple, en ligne (batch)
# 5  Fully Implicit Simple, en ligne (batch)
# 6  Fully Implicit Simple, en ligne (batch)
# 7  Fully Implicit Simple, en ligne (batch)
# 8  Fully Implicit Simple, en ligne (batch)
# 9  Fully Implicit Simple, en ligne (batch)

# %% [markdown]
# ### Fully Implicit Recommender avec nuls sans indicateur, hors ligne

# %%
# %%time
FullyImplicitRecommenderWithNull_no_indicator_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartFullyImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull_no_indicator, 
                                           n_loop=n_loop, n_pred=n_pred,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 24.2 s, sys: 229 ms, total: 24.4 s
# Wall time: 34.8 s

# %%
FullyImplicitRecommenderWithNull_no_indicator_df_normalized = normalized_results(FullyImplicitRecommenderWithNull_no_indicator_df, 'Fully Implicit Null, hors ligne')
FullyImplicitRecommenderWithNull_no_indicator_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  994.470472   72.904080      251.375485             0.40
# 1  954.143507   73.823604      227.591311             0.32
# 2  999.614067   81.048467      219.774438             0.31
# 3  987.932275   79.096638      154.574909             0.25
# 4  983.683003   67.423240      126.547580             0.21
# 5  987.576756   68.356412      193.314221             0.33
# 6  985.261628   71.612300      263.922071             0.44
# 7  991.443539   74.712781      205.704981             0.29
# 8  997.731759   77.304048      238.057000             0.38
# 9  931.476631   71.714570      222.595339             0.35
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.252773                        3.448030
# 1                       0.238529                        3.082907
# 2                       0.219859                        2.711642
# 3                       0.156463                        1.954254
# 4                       0.128647                        1.876913
# 5                       0.195746                        2.828033
# 6                       0.267870                        3.685429
# 7                       0.207480                        2.753277
# 8                       0.238598                        3.079489
# 9                       0.238970                        3.103907
#
#                     recommendation
# 0  Fully Implicit Null, hors ligne
# 1  Fully Implicit Null, hors ligne
# 2  Fully Implicit Null, hors ligne
# 3  Fully Implicit Null, hors ligne
# 4  Fully Implicit Null, hors ligne
# 5  Fully Implicit Null, hors ligne
# 6  Fully Implicit Null, hors ligne
# 7  Fully Implicit Null, hors ligne
# 8  Fully Implicit Null, hors ligne
# 9  Fully Implicit Null, hors ligne

# %% [markdown]
# ### Fully Implicit Recommender avec nuls sans indicateur, en ligne

# %%
# %%time
FullyImplicitRecommenderWithNull_no_indicator_online_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartFullyImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull_no_indicator,
                                           n_loop=n_loop, n_pred=n_pred,
                                           online_batch_size=1,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 22 s, sys: 209 ms, total: 22.2 s
# Wall time: 32.3 s

# %%
FullyImplicitRecommenderWithNull_no_indicator_online_df_normalized = normalized_results(FullyImplicitRecommenderWithNull_no_indicator_online_df,
                                                                                   'Fully Implicit Null, en ligne')
FullyImplicitRecommenderWithNull_no_indicator_online_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  998.921306   84.547036      227.589541             0.33
# 1  979.090110   68.692165      171.988262             0.32
# 2  978.956422   76.835236      118.265321             0.25
# 3  982.233577   66.475224      104.452611             0.22
# 4  992.197550   64.996257      153.598562             0.29
# 5  989.472009   61.984819      212.396431             0.40
# 6  997.837451   75.401258      209.001969             0.41
# 7  978.415302   82.353642      171.823930             0.27
# 8  899.955854   73.961810      156.450188             0.29
# 9  985.460665   79.662900      192.741886             0.32
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.227835                        2.691869
# 1                       0.175661                        2.503754
# 2                       0.120808                        1.539207
# 3                       0.106342                        1.571301
# 4                       0.154806                        2.363191
# 5                       0.214656                        3.426588
# 6                       0.209455                        2.771863
# 7                       0.175615                        2.086416
# 8                       0.173842                        2.115283
# 9                       0.195586                        2.419469
#
#                   recommendation
# 0  Fully Implicit Null, en ligne
# 1  Fully Implicit Null, en ligne
# 2  Fully Implicit Null, en ligne
# 3  Fully Implicit Null, en ligne
# 4  Fully Implicit Null, en ligne
# 5  Fully Implicit Null, en ligne
# 6  Fully Implicit Null, en ligne
# 7  Fully Implicit Null, en ligne
# 8  Fully Implicit Null, en ligne
# 9  Fully Implicit Null, en ligne

# %% [markdown]
# ### Fully Implicit Recommender avec nuls sans indicateur, en ligne version batch

# %%
# %%time
FullyImplicitRecommenderWithNull_no_indicator_online_batch_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartFullyImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull_no_indicator,
                                           n_loop=n_loop, n_pred=n_pred,
                                           online_batch_size=online_batch_size,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 22.4 s, sys: 208 ms, total: 22.7 s
# Wall time: 34.3 s

# %%
FullyImplicitRecommenderWithNull_no_indicator_online_batch_df_normalized = \
    normalized_results(FullyImplicitRecommenderWithNull_no_indicator_online_batch_df, 'Fully Implicit Null, en ligne (batch)')
FullyImplicitRecommenderWithNull_no_indicator_online_batch_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  999.065682   72.249758      190.637215             0.34
# 1  995.891831   75.781023      155.900995             0.28
# 2  933.851535   63.737690       94.984681             0.18
# 3  998.000882   69.733078      127.657787             0.24
# 4  993.758308   72.468104      148.354593             0.36
# 5  958.025152   67.358137      178.260356             0.35
# 6  974.963566   73.860653      212.640438             0.33
# 7  988.779737   81.204659      204.875622             0.33
# 8  995.677339   70.461475      169.685828             0.30
# 9  884.202923   64.972706      159.340409             0.28
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.190815                        2.638586
# 1                       0.156544                        2.057256
# 2                       0.101713                        1.490244
# 3                       0.127914                        1.830663
# 4                       0.149286                        2.047171
# 5                       0.186071                        2.646456
# 6                       0.218101                        2.878941
# 7                       0.207200                        2.522954
# 8                       0.170423                        2.408207
# 9                       0.180208                        2.452421
#
#                           recommendation
# 0  Fully Implicit Null, en ligne (batch)
# 1  Fully Implicit Null, en ligne (batch)
# 2  Fully Implicit Null, en ligne (batch)
# 3  Fully Implicit Null, en ligne (batch)
# 4  Fully Implicit Null, en ligne (batch)
# 5  Fully Implicit Null, en ligne (batch)
# 6  Fully Implicit Null, en ligne (batch)
# 7  Fully Implicit Null, en ligne (batch)
# 8  Fully Implicit Null, en ligne (batch)
# 9  Fully Implicit Null, en ligne (batch)

# %% [markdown]
# ### Fully Implicit Recommender avec nuls et indicateur binaire, hors ligne

# %%
# %%time
FullyImplicitRecommenderWithNull_binary_indicator_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartFullyImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull_binary_indicator,
                                           n_loop=n_loop, n_pred=n_pred,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 22.6 s, sys: 199 ms, total: 22.8 s
# Wall time: 37.7 s

# %%
FullyImplicitRecommenderWithNull_binary_indicator_df_normalized = normalized_results(FullyImplicitRecommenderWithNull_binary_indicator_df,
                                                                                'Fully Implicit Null binaire, hors ligne')
FullyImplicitRecommenderWithNull_binary_indicator_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  999.393910   79.797400      172.473282             0.28
# 1  996.152662   67.758561      146.355229             0.28
# 2  950.127668   67.042217      226.844160             0.44
# 3  993.970366   80.534726      159.534848             0.28
# 4  976.233708   67.730686      201.535728             0.31
# 5  986.202090   85.638074      230.634128             0.30
# 6  974.888863   64.919526      209.849949             0.36
# 7  990.621220   84.451157      201.840564             0.32
# 8  988.732881   77.750081      207.911784             0.32
# 9  994.850604   88.497575      216.326975             0.34
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.172578                        2.161390
# 1                       0.146920                        2.159952
# 2                       0.238751                        3.383602
# 3                       0.160503                        1.980945
# 4                       0.206442                        2.975545
# 5                       0.233861                        2.693126
# 6                       0.215255                        3.232463
# 7                       0.203752                        2.390027
# 8                       0.210281                        2.674104
# 9                       0.217447                        2.444440
#
#                             recommendation
# 0  Fully Implicit Null binaire, hors ligne
# 1  Fully Implicit Null binaire, hors ligne
# 2  Fully Implicit Null binaire, hors ligne
# 3  Fully Implicit Null binaire, hors ligne
# 4  Fully Implicit Null binaire, hors ligne
# 5  Fully Implicit Null binaire, hors ligne
# 6  Fully Implicit Null binaire, hors ligne
# 7  Fully Implicit Null binaire, hors ligne
# 8  Fully Implicit Null binaire, hors ligne
# 9  Fully Implicit Null binaire, hors ligne

# %% [markdown]
# ### Fully Implicit Recommender avec nuls et indicateur binaire, en ligne

# %%
# %%time
FullyImplicitRecommenderWithNull_binary_indicator_online_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartFullyImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull_binary_indicator,
                                           n_loop=n_loop, n_pred=n_pred,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 23.4 s, sys: 250 ms, total: 23.7 s
# Wall time: 51.2 s

# %%
FullyImplicitRecommenderWithNull_binary_indicator_online_df_normalized = normalized_results(FullyImplicitRecommenderWithNull_binary_indicator_online_df,
                                                                                       'Fully Implicit Null binaire, en ligne')
FullyImplicitRecommenderWithNull_binary_indicator_online_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  968.222203   68.019155      178.537434             0.30
# 1  988.390872   80.869466      191.844468             0.31
# 2  978.337027   71.933848      208.146790             0.35
# 3  909.593855   62.310225      190.635081             0.35
# 4  942.628856   77.498732      237.111674             0.36
# 5  958.829268   60.997560      156.102892             0.35
# 6  987.668063   76.567920      167.362018             0.28
# 7  956.151676   76.898539      188.894549             0.32
# 8  973.921530   78.770110      185.361652             0.33
# 9  993.719660   65.508523      266.253265             0.40
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.184397                        2.624811
# 1                       0.194098                        2.372273
# 2                       0.212756                        2.893586
# 3                       0.209583                        3.059451
# 4                       0.251543                        3.059556
# 5                       0.162806                        2.559166
# 6                       0.169452                        2.185798
# 7                       0.197557                        2.456413
# 8                       0.190325                        2.353198
# 9                       0.267936                        4.064406
#
#                           recommendation
# 0  Fully Implicit Null binaire, en ligne
# 1  Fully Implicit Null binaire, en ligne
# 2  Fully Implicit Null binaire, en ligne
# 3  Fully Implicit Null binaire, en ligne
# 4  Fully Implicit Null binaire, en ligne
# 5  Fully Implicit Null binaire, en ligne
# 6  Fully Implicit Null binaire, en ligne
# 7  Fully Implicit Null binaire, en ligne
# 8  Fully Implicit Null binaire, en ligne
# 9  Fully Implicit Null binaire, en ligne

# %% [markdown]
# ### Fully Implicit Recommender avec nuls et indicateur binaire, en ligne version batch

# %%
# %%time
FullyImplicitRecommenderWithNull_binary_indicator_online_batch_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartFullyImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull_binary_indicator,
                                           n_loop=n_loop, n_pred=n_pred,
                                           online_batch_size=online_batch_size,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 23.9 s, sys: 229 ms, total: 24.2 s
# Wall time: 49.2 s

# %%
FullyImplicitRecommenderWithNull_binary_indicator_online_batch_df_normalized = \
    normalized_results(FullyImplicitRecommenderWithNull_binary_indicator_online_batch_df, 'Fully Implicit Null binaire, en ligne (batch)')
FullyImplicitRecommenderWithNull_binary_indicator_online_batch_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  894.198304   72.539908      218.265973             0.40
# 1  962.652740   86.229295      216.447936             0.31
# 2  956.370585   74.184177      240.775026             0.37
# 3  970.736137   76.042599      140.009871             0.29
# 4  956.976297   72.453262      201.604730             0.40
# 5  976.612282   72.716363      175.173055             0.28
# 6  944.002084   79.850076      233.630704             0.34
# 7  973.089772   69.536520      189.752470             0.31
# 8  967.054285   73.682918      218.570313             0.36
# 9  924.626016   63.817433      143.788443             0.32
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.244091                        3.008909
# 1                       0.224845                        2.510144
# 2                       0.251759                        3.245639
# 3                       0.144231                        1.841203
# 4                       0.210668                        2.782549
# 5                       0.179368                        2.408991
# 6                       0.247490                        2.925867
# 7                       0.195000                        2.728817
# 8                       0.226017                        2.966363
# 9                       0.155510                        2.253122
#
#                                   recommendation
# 0  Fully Implicit Null binaire, en ligne (batch)
# 1  Fully Implicit Null binaire, en ligne (batch)
# 2  Fully Implicit Null binaire, en ligne (batch)
# 3  Fully Implicit Null binaire, en ligne (batch)
# 4  Fully Implicit Null binaire, en ligne (batch)
# 5  Fully Implicit Null binaire, en ligne (batch)
# 6  Fully Implicit Null binaire, en ligne (batch)
# 7  Fully Implicit Null binaire, en ligne (batch)
# 8  Fully Implicit Null binaire, en ligne (batch)
# 9  Fully Implicit Null binaire, en ligne (batch)

# %% [markdown]
# ### Fully Implicit Recommender avec nuls et indicateur special, hors ligne

# %%
# %%time
FullyImplicitRecommenderWithNull_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartFullyImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull,
                                           n_loop=n_loop, n_pred=n_pred,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 24.3 s, sys: 187 ms, total: 24.5 s
# Wall time: 34.7 s

# %%
FullyImplicitRecommenderWithNull_df_normalized = normalized_results(FullyImplicitRecommenderWithNull_df, 'Fully Implicit Null special, hors ligne')
FullyImplicitRecommenderWithNull_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  993.851719   70.662258      242.107036             0.41
# 1  947.365555   80.501416      140.497814             0.22
# 2  999.435935   75.218148      199.971551             0.37
# 3  925.176521   63.946814      113.969178             0.26
# 4  965.437264   67.884943      115.608592             0.24
# 5  913.081130   55.622832      195.404107             0.36
# 6  984.248872   82.806610      259.913699             0.33
# 7  995.527074   66.846428      198.054778             0.40
# 8  985.562354   76.517832      177.014918             0.29
# 9  954.520305   68.548018      167.557087             0.32
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.243605                        3.426257
# 1                       0.148304                        1.745284
# 2                       0.200084                        2.658555
# 3                       0.123186                        1.782250
# 4                       0.119747                        1.703008
# 5                       0.214005                        3.513020
# 6                       0.264073                        3.138804
# 7                       0.198945                        2.962833
# 8                       0.179608                        2.313381
# 9                       0.175541                        2.444375
#
#                             recommendation
# 0  Fully Implicit Null special, hors ligne
# 1  Fully Implicit Null special, hors ligne
# 2  Fully Implicit Null special, hors ligne
# 3  Fully Implicit Null special, hors ligne
# 4  Fully Implicit Null special, hors ligne
# 5  Fully Implicit Null special, hors ligne
# 6  Fully Implicit Null special, hors ligne
# 7  Fully Implicit Null special, hors ligne
# 8  Fully Implicit Null special, hors ligne
# 9  Fully Implicit Null special, hors ligne

# %% [markdown]
# ### Fully Implicit Recommender avec nuls et indicateur special, en ligne

# %%
# %%time
FullyImplicitRecommenderWithNull_online_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartFullyImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull,
                                           n_loop=n_loop, n_pred=n_pred,
                                           online_batch_size=1,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 26.2 s, sys: 252 ms, total: 26.4 s
# Wall time: 52.9 s

# %%
FullyImplicitRecommenderWithNull_online_df_normalized = normalized_results(FullyImplicitRecommenderWithNull_online_df, 'Fully Implicit Null special, en ligne')
FullyImplicitRecommenderWithNull_online_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  980.270047   78.768094      159.322953             0.30
# 1  962.791178   75.427980      121.135531             0.27
# 2  894.329185   68.674252      183.020946             0.37
# 3  997.566458   67.299071      157.309190             0.28
# 4  975.100623   85.470132      257.712994             0.39
# 5  954.919102   72.887752      170.885592             0.31
# 6  979.028459   62.185083      123.086606             0.38
# 7  957.099851   78.304723      171.278941             0.30
# 8  998.644645   82.125972      159.467428             0.24
# 9  962.825170   72.057402      208.254487             0.37
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.162530                        2.022684
# 1                       0.125817                        1.605976
# 2                       0.204646                        2.665059
# 3                       0.157693                        2.337465
# 4                       0.264294                        3.015240
# 5                       0.178953                        2.344504
# 6                       0.125723                        1.979359
# 7                       0.178956                        2.187339
# 8                       0.159684                        1.941742
# 9                       0.216295                        2.890119
#
#                           recommendation
# 0  Fully Implicit Null special, en ligne
# 1  Fully Implicit Null special, en ligne
# 2  Fully Implicit Null special, en ligne
# 3  Fully Implicit Null special, en ligne
# 4  Fully Implicit Null special, en ligne
# 5  Fully Implicit Null special, en ligne
# 6  Fully Implicit Null special, en ligne
# 7  Fully Implicit Null special, en ligne
# 8  Fully Implicit Null special, en ligne
# 9  Fully Implicit Null special, en ligne

# %% [markdown]
# ### Fully Implicit Recommender avec nuls et indicateur special, en ligne version batch

# %%
# %%time
FullyImplicitRecommenderWithNull_online_batch_df = \
    eval_loop_ColdStartImplicitRecommender(ColdStartRecommenderClass=ColdStartFullyImplicitRecommender,
                                           ImplicitRecommenderClass=ImplicitRecommenderWithNull,
                                           n_loop=n_loop, n_pred=n_pred,
                                           online_batch_size=online_batch_size,
                                           user_dim=user_dim, item_dim=item_dim,
                                           n_hidden=n_hidden, hidden_size=hidden_size, 
                                           dropout=dropout, l2_reg=l2_reg)
# Out:
# CPU times: user 24 s, sys: 218 ms, total: 24.2 s
# Wall time: 37.7 s

# %%
FullyImplicitRecommenderWithNull_online_batch_df_normalized = \
    normalized_results(FullyImplicitRecommenderWithNull_online_batch_df, 'Fully Implicit Null special, en ligne (batch)')
FullyImplicitRecommenderWithNull_online_batch_df_normalized
# Out:
#     max_price  mean_price  average_reward  good_reco_ratio  \
# 0  981.050832   76.476955      203.781578             0.41
# 1  995.783810   80.310726      190.235705             0.32
# 2  982.721539   70.483110      217.744193             0.35
# 3  993.274066   76.286364      210.975146             0.35
# 4  994.025982   69.652098      216.240535             0.35
# 5  964.931752   78.198929      205.072753             0.31
# 6  926.213093   76.257912      126.342980             0.25
# 7  987.508670   64.945605      199.038306             0.31
# 8  959.315920   69.047777      171.278664             0.32
# 9  884.369669   67.108326      141.348904             0.27
#
#    average_reward_normalized_max  average_reward_normalized_mean  \
# 0                       0.207718                        2.664614
# 1                       0.191041                        2.368746
# 2                       0.221573                        3.089310
# 3                       0.212404                        2.765568
# 4                       0.217540                        3.104580
# 5                       0.212526                        2.622450
# 6                       0.136408                        1.656785
# 7                       0.201556                        3.064692
# 8                       0.178543                        2.480582
# 9                       0.159830                        2.106280
#
#                                   recommendation
# 0  Fully Implicit Null special, en ligne (batch)
# 1  Fully Implicit Null special, en ligne (batch)
# 2  Fully Implicit Null special, en ligne (batch)
# 3  Fully Implicit Null special, en ligne (batch)
# 4  Fully Implicit Null special, en ligne (batch)
# 5  Fully Implicit Null special, en ligne (batch)
# 6  Fully Implicit Null special, en ligne (batch)
# 7  Fully Implicit Null special, en ligne (batch)
# 8  Fully Implicit Null special, en ligne (batch)
# 9  Fully Implicit Null special, en ligne (batch)

# %% [markdown]
# ## Aggregation des résutats

# %%
all_results = pd.concat( (
    ImplicitRecommenderSimple_df_normalized,
    ImplicitRecommenderSimple_online_df_normalized,
    ImplicitRecommenderSimple_online_batch_df_normalized,
    ImplicitRecommenderWithNull_no_indicator_df_normalized,
    ImplicitRecommenderWithNull_no_indicator_online_df_normalized,
    ImplicitRecommenderWithNull_no_indicator_online_batch_df_normalized,
    ImplicitRecommenderWithNull_binary_indicator_df_normalized,
    ImplicitRecommenderWithNull_binary_indicator_online_df_normalized,
    ImplicitRecommenderWithNull_binary_indicator_online_batch_df_normalized,
    ImplicitRecommenderWithNull_df_normalized,
    ImplicitRecommenderWithNull_online_df_normalized,
    ImplicitRecommenderWithNull_online_batch_df_normalized,
    
    FullyImplicitRecommenderSimple_df_normalized,
    FullyImplicitRecommenderSimple_online_df_normalized,
    FullyImplicitRecommenderSimple_online_batch_df_normalized,
    FullyImplicitRecommenderWithNull_no_indicator_df_normalized,
    FullyImplicitRecommenderWithNull_no_indicator_online_df_normalized,
    FullyImplicitRecommenderWithNull_no_indicator_online_batch_df_normalized,
    FullyImplicitRecommenderWithNull_binary_indicator_df_normalized,
    FullyImplicitRecommenderWithNull_binary_indicator_online_df_normalized,
    FullyImplicitRecommenderWithNull_binary_indicator_online_batch_df_normalized,
    FullyImplicitRecommenderWithNull_df_normalized,
    FullyImplicitRecommenderWithNull_online_df_normalized,
    FullyImplicitRecommenderWithNull_online_batch_df_normalized
), axis = 0)

# %%
aggregat = all_results.groupby('recommendation').mean()

# %% [markdown]
# ### Classement ratio de recommandations effectives

# %%
col = 'good_reco_ratio' 
aggregat.sort_values(col, ascending=False)\
    .style.apply((lambda x: ['background: lightgreen' if x.name == col else '' for _ in x]))
# Out:
# <style  type="text/css" >
#     #T_07f76a10_3b51_11e9_afbd_313de2e40688row0_col3 {
#             background:  lightgreen;
#         }    #T_07f76a10_3b51_11e9_afbd_313de2e40688row1_col3 {
#             background:  lightgreen;
#         }    #T_07f76a10_3b51_11e9_afbd_313de2e40688row2_col3 {
#             background:  lightgreen;
#         }    #T_07f76a10_3b51_11e9_afbd_313de2e40688row3_col3 {
#             background:  lightgreen;
#         }    #T_07f76a10_3b51_11e9_afbd_313de2e40688row4_col3 {
#             background:  lightgreen;
#         }    #T_07f76a10_3b51_11e9_afbd_313de2e40688row5_col3 {
#             background:  lightgreen;
#         }    #T_07f76a10_3b51_11e9_afbd_313de2e40688row6_col3 {
#             background:  lightgreen;
#         }    #T_07f76a10_3b51_11e9_afbd_313de2e40688row7_col3 {
#             background:  lightgreen;
#         }    #T_07f76a10_3b51_11e9_afbd_313de2e40688row8_col3 {
#             background:  lightgreen;
#         }    #T_07f76a10_3b51_11e9_afbd_313de2e40688row9_col3 {
#             background:  lightgreen;
#         }    #T_07f76a10_3b51_11e9_afbd_313de2e40688row10_col3 {
#             background:  lightgreen;
#         }    #T_07f76a10_3b51_11e9_afbd_313de2e40688row11_col3 {
#             background:  lightgreen;
#         }    #T_07f76a10_3b51_11e9_afbd_313de2e40688row12_col3 {
#             background:  lightgreen;
#         }    #T_07f76a10_3b51_11e9_afbd_313de2e40688row13_col3 {
#             background:  lightgreen;
#         }    #T_07f76a10_3b51_11e9_afbd_313de2e40688row14_col3 {
#             background:  lightgreen;
#         }    #T_07f76a10_3b51_11e9_afbd_313de2e40688row15_col3 {
#             background:  lightgreen;
#         }    #T_07f76a10_3b51_11e9_afbd_313de2e40688row16_col3 {
#             background:  lightgreen;
#         }    #T_07f76a10_3b51_11e9_afbd_313de2e40688row17_col3 {
#             background:  lightgreen;
#         }    #T_07f76a10_3b51_11e9_afbd_313de2e40688row18_col3 {
#             background:  lightgreen;
#         }    #T_07f76a10_3b51_11e9_afbd_313de2e40688row19_col3 {
#             background:  lightgreen;
#         }    #T_07f76a10_3b51_11e9_afbd_313de2e40688row20_col3 {
#             background:  lightgreen;
#         }    #T_07f76a10_3b51_11e9_afbd_313de2e40688row21_col3 {
#             background:  lightgreen;
#         }    #T_07f76a10_3b51_11e9_afbd_313de2e40688row22_col3 {
#             background:  lightgreen;
#         }    #T_07f76a10_3b51_11e9_afbd_313de2e40688row23_col3 {
#             background:  lightgreen;
#         }</style><table id="T_07f76a10_3b51_11e9_afbd_313de2e40688" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >max_price</th>        <th class="col_heading level0 col1" >mean_price</th>        <th class="col_heading level0 col2" >average_reward</th>        <th class="col_heading level0 col3" >good_reco_ratio</th>        <th class="col_heading level0 col4" >average_reward_normalized_max</th>        <th class="col_heading level0 col5" >average_reward_normalized_mean</th>    </tr>    <tr>        <th class="index_name level0" >recommendation</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_07f76a10_3b51_11e9_afbd_313de2e40688level0_row0" class="row_heading level0 row0" >Fully Implicit Simple, en ligne</th>
#                         <td id="T_07f76a10_3b51_11e9_afbd_313de2e40688row0_col0" class="data row0 col0" >949.591</td>
#                         <td id="T_07f76a10_3b51_11e9_afbd_313de2e40688row0_col1" class="data row0 col1" >70.1785</td>
#                         <td id="T_07f76a10_3b51_11e9_afbd_313de2e40688row0_col2" class="data row0 col2" >186.392</td>
#                         <td id="T_07f76a10_3b51_11e9_afbd_313de2e40688row0_col3" class="data row0 col3" >0.341</td>
#                         <td id="T_07f76a10_3b51_11e9_afbd_313de2e40688row0_col4" class="data row0 col4" >0.195057</td>
#                         <td id="T_07f76a10_3b51_11e9_afbd_313de2e40688row0_col5" class="data row0 col5" >2.66184</td>
#             </tr>
#             <tr>
#                         <th id="T_07f76a10_3b51_11e9_afbd_313de2e40688level0_row1" class="row_heading level0 row1" >Fully Implicit Null binaire, en ligne (batch)</th>
#                         <td id="T_07f76a10_3b51_11e9_afbd_313de2e40688row1_col0" class="data row1 col0" >952.632</td>
#                         <td id="T_07f76a10_3b51_11e9_afbd_313de2e40688row1_col1" class="data row1 col1" >74.1053</td>
#                         <td id="T_07f76a10_3b51_11e9_afbd_313de2e40688row1_col2" class="data row1 col2" >197.802</td>
#                         <td id="T_07f76a10_3b51_11e9_afbd_313de2e40688row1_col3" class="data row1 col3" >0.338</td>
#                         <td id="T_07f76a10_3b51_11e9_afbd_313de2e40688row1_col4" class="data row1 col4" >0.207898</td>
#                         <td id="T_07f76a10_3b51_11e9_afbd_313de2e40688row1_col5" class="data row1 col5" >2.66716</td>
#             </tr>
#             <tr>
#                         <th id="T_07f76a10_3b51_11e9_afbd_313de2e40688level0_row2" class="row_heading level0 row2" >Fully Implicit Null binaire, en ligne</th>
#                         <td id="T_07f76a10_3b51_11e9_afbd_313de2e40688row2_col0" class="data row2 col0" >965.746</td>
#                         <td id="T_07f76a10_3b51_11e9_afbd_313de2e40688row2_col1" class="data row2 col1" >71.9374</td>
#                         <td id="T_07f76a10_3b51_11e9_afbd_313de2e40688row2_col2" class="data row2 col2" >197.025</td>
#                         <td id="T_07f76a10_3b51_11e9_afbd_313de2e40688row2_col3" class="data row2 col3" >0.335</td>
#                         <td id="T_07f76a10_3b51_11e9_afbd_313de2e40688row2_col4" class="data row2 col4" >0.204045</td>
#                         <td id="T_07f76a10_3b51_11e9_afbd_313de2e40688row2_col5" class="data row2 col5" >2.76287</td>
#             </tr>
#             <tr>
#                         <th id="T_07f76a10_3b51_11e9_afbd_313de2e40688level0_row3" class="row_heading level0 row3" >Null special, hors ligne</th>
#                         <td id="T_07f76a10_3b51_11e9_afbd_313de2e40688row3_col0" class="data row3 col0" >958.93</td>
#                         <td id="T_07f76a10_3b51_11e9_afbd_313de2e40688row3_col1" class="data row3 col1" >68.4424</td>
#                         <td id="T_07f76a10_3b51_11e9_afbd_313de2e40688row3_col2" class="data row3 col2" >182.678</td>
#                         <td id="T_07f76a10_3b51_11e9_afbd_313de2e40688row3_col3" class="data row3 col3" >0.331</td>
#                         <td id="T_07f76a10_3b51_11e9_afbd_313de2e40688row3_col4" class="data row3 col4" >0.191525</td>
#                         <td id="T_07f76a10_3b51_11e9_afbd_313de2e40688row3_col5" class="data row3 col5" >2.67524</td>
#             </tr>
#             <tr>
#                         <th id="T_07f76a10_3b51_11e9_afbd_313de2e40688level0_row4" class="row_heading level0 row4" >Fully Implicit Null, hors ligne</th>
#                         <td id="T_07f76a10_3b51_11e9_afbd_313de2e40688row4_col0" class="data row4 col0" >981.333</td>
#                         <td id="T_07f76a10_3b51_11e9_afbd_313de2e40688row4_col1" class="data row4 col1" >73.7996</td>
#                         <td id="T_07f76a10_3b51_11e9_afbd_313de2e40688row4_col2" class="data row4 col2" >210.346</td>
#                         <td id="T_07f76a10_3b51_11e9_afbd_313de2e40688row4_col3" class="data row4 col3" >0.328</td>
#                         <td id="T_07f76a10_3b51_11e9_afbd_313de2e40688row4_col4" class="data row4 col4" >0.214494</td>
#                         <td id="T_07f76a10_3b51_11e9_afbd_313de2e40688row4_col5" class="data row4 col5" >2.85239</td>
#             </tr>
#             <tr>
#                         <th id="T_07f76a10_3b51_11e9_afbd_313de2e40688level0_row5" class="row_heading level0 row5" >Null special, en ligne</th>
#                         <td id="T_07f76a10_3b51_11e9_afbd_313de2e40688r

# %% [markdown]
# ### Classement par average reward normalisée (max)

# %%
col = 'average_reward_normalized_max' 
aggregat.sort_values(col, ascending=False)\
    .style.apply((lambda x: ['background: lightgreen' if x.name == col else '' for _ in x]))
# Out:
# <style  type="text/css" >
#     #T_08000832_3b51_11e9_afbd_313de2e40688row0_col4 {
#             background:  lightgreen;
#         }    #T_08000832_3b51_11e9_afbd_313de2e40688row1_col4 {
#             background:  lightgreen;
#         }    #T_08000832_3b51_11e9_afbd_313de2e40688row2_col4 {
#             background:  lightgreen;
#         }    #T_08000832_3b51_11e9_afbd_313de2e40688row3_col4 {
#             background:  lightgreen;
#         }    #T_08000832_3b51_11e9_afbd_313de2e40688row4_col4 {
#             background:  lightgreen;
#         }    #T_08000832_3b51_11e9_afbd_313de2e40688row5_col4 {
#             background:  lightgreen;
#         }    #T_08000832_3b51_11e9_afbd_313de2e40688row6_col4 {
#             background:  lightgreen;
#         }    #T_08000832_3b51_11e9_afbd_313de2e40688row7_col4 {
#             background:  lightgreen;
#         }    #T_08000832_3b51_11e9_afbd_313de2e40688row8_col4 {
#             background:  lightgreen;
#         }    #T_08000832_3b51_11e9_afbd_313de2e40688row9_col4 {
#             background:  lightgreen;
#         }    #T_08000832_3b51_11e9_afbd_313de2e40688row10_col4 {
#             background:  lightgreen;
#         }    #T_08000832_3b51_11e9_afbd_313de2e40688row11_col4 {
#             background:  lightgreen;
#         }    #T_08000832_3b51_11e9_afbd_313de2e40688row12_col4 {
#             background:  lightgreen;
#         }    #T_08000832_3b51_11e9_afbd_313de2e40688row13_col4 {
#             background:  lightgreen;
#         }    #T_08000832_3b51_11e9_afbd_313de2e40688row14_col4 {
#             background:  lightgreen;
#         }    #T_08000832_3b51_11e9_afbd_313de2e40688row15_col4 {
#             background:  lightgreen;
#         }    #T_08000832_3b51_11e9_afbd_313de2e40688row16_col4 {
#             background:  lightgreen;
#         }    #T_08000832_3b51_11e9_afbd_313de2e40688row17_col4 {
#             background:  lightgreen;
#         }    #T_08000832_3b51_11e9_afbd_313de2e40688row18_col4 {
#             background:  lightgreen;
#         }    #T_08000832_3b51_11e9_afbd_313de2e40688row19_col4 {
#             background:  lightgreen;
#         }    #T_08000832_3b51_11e9_afbd_313de2e40688row20_col4 {
#             background:  lightgreen;
#         }    #T_08000832_3b51_11e9_afbd_313de2e40688row21_col4 {
#             background:  lightgreen;
#         }    #T_08000832_3b51_11e9_afbd_313de2e40688row22_col4 {
#             background:  lightgreen;
#         }    #T_08000832_3b51_11e9_afbd_313de2e40688row23_col4 {
#             background:  lightgreen;
#         }</style><table id="T_08000832_3b51_11e9_afbd_313de2e40688" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >max_price</th>        <th class="col_heading level0 col1" >mean_price</th>        <th class="col_heading level0 col2" >average_reward</th>        <th class="col_heading level0 col3" >good_reco_ratio</th>        <th class="col_heading level0 col4" >average_reward_normalized_max</th>        <th class="col_heading level0 col5" >average_reward_normalized_mean</th>    </tr>    <tr>        <th class="index_name level0" >recommendation</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_08000832_3b51_11e9_afbd_313de2e40688level0_row0" class="row_heading level0 row0" >Null special, en ligne</th>
#                         <td id="T_08000832_3b51_11e9_afbd_313de2e40688row0_col0" class="data row0 col0" >963.908</td>
#                         <td id="T_08000832_3b51_11e9_afbd_313de2e40688row0_col1" class="data row0 col1" >70.0815</td>
#                         <td id="T_08000832_3b51_11e9_afbd_313de2e40688row0_col2" class="data row0 col2" >230.922</td>
#                         <td id="T_08000832_3b51_11e9_afbd_313de2e40688row0_col3" class="data row0 col3" >0.325</td>
#                         <td id="T_08000832_3b51_11e9_afbd_313de2e40688row0_col4" class="data row0 col4" >0.237329</td>
#                         <td id="T_08000832_3b51_11e9_afbd_313de2e40688row0_col5" class="data row0 col5" >3.30483</td>
#             </tr>
#             <tr>
#                         <th id="T_08000832_3b51_11e9_afbd_313de2e40688level0_row1" class="row_heading level0 row1" >Fully Implicit Null, hors ligne</th>
#                         <td id="T_08000832_3b51_11e9_afbd_313de2e40688row1_col0" class="data row1 col0" >981.333</td>
#                         <td id="T_08000832_3b51_11e9_afbd_313de2e40688row1_col1" class="data row1 col1" >73.7996</td>
#                         <td id="T_08000832_3b51_11e9_afbd_313de2e40688row1_col2" class="data row1 col2" >210.346</td>
#                         <td id="T_08000832_3b51_11e9_afbd_313de2e40688row1_col3" class="data row1 col3" >0.328</td>
#                         <td id="T_08000832_3b51_11e9_afbd_313de2e40688row1_col4" class="data row1 col4" >0.214494</td>
#                         <td id="T_08000832_3b51_11e9_afbd_313de2e40688row1_col5" class="data row1 col5" >2.85239</td>
#             </tr>
#             <tr>
#                         <th id="T_08000832_3b51_11e9_afbd_313de2e40688level0_row2" class="row_heading level0 row2" >Fully Implicit Null binaire, en ligne (batch)</th>
#                         <td id="T_08000832_3b51_11e9_afbd_313de2e40688row2_col0" class="data row2 col0" >952.632</td>
#                         <td id="T_08000832_3b51_11e9_afbd_313de2e40688row2_col1" class="data row2 col1" >74.1053</td>
#                         <td id="T_08000832_3b51_11e9_afbd_313de2e40688row2_col2" class="data row2 col2" >197.802</td>
#                         <td id="T_08000832_3b51_11e9_afbd_313de2e40688row2_col3" class="data row2 col3" >0.338</td>
#                         <td id="T_08000832_3b51_11e9_afbd_313de2e40688row2_col4" class="data row2 col4" >0.207898</td>
#                         <td id="T_08000832_3b51_11e9_afbd_313de2e40688row2_col5" class="data row2 col5" >2.66716</td>
#             </tr>
#             <tr>
#                         <th id="T_08000832_3b51_11e9_afbd_313de2e40688level0_row3" class="row_heading level0 row3" >Fully Implicit Null binaire, en ligne</th>
#                         <td id="T_08000832_3b51_11e9_afbd_313de2e40688row3_col0" class="data row3 col0" >965.746</td>
#                         <td id="T_08000832_3b51_11e9_afbd_313de2e40688row3_col1" class="data row3 col1" >71.9374</td>
#                         <td id="T_08000832_3b51_11e9_afbd_313de2e40688row3_col2" class="data row3 col2" >197.025</td>
#                         <td id="T_08000832_3b51_11e9_afbd_313de2e40688row3_col3" class="data row3 col3" >0.335</td>
#                         <td id="T_08000832_3b51_11e9_afbd_313de2e40688row3_col4" class="data row3 col4" >0.204045</td>
#                         <td id="T_08000832_3b51_11e9_afbd_313de2e40688row3_col5" class="data row3 col5" >2.76287</td>
#             </tr>
#             <tr>
#                         <th id="T_08000832_3b51_11e9_afbd_313de2e40688level0_row4" class="row_heading level0 row4" >Fully Implicit Null binaire, hors ligne</th>
#                         <td id="T_08000832_3b51_11e9_afbd_313de2e40688row4_col0" class="data row4 col0" >985.117</td>
#                         <td id="T_08000832_3b51_11e9_afbd_313de2e40688row4_col1" class="data row4 col1" >76.412</td>
#                         <td id="T_08000832_3b51_11e9_afbd_313de2e40688row4_col2" class="data row4 col2" >197.331</td>
#                         <td id="T_08000832_3b51_11e9_afbd_313de2e40688row4_col3" class="data row4 col3" >0.323</td>
#                         <td id="T_08000832_3b51_11e9_afbd_313de2e40688row4_col4" class="data row4 col4" >0.200579</td>
#                         <td id="T_08000832_3b51_11e9_afbd_313de2e40688row4_col5" class="data row4 col5" >2.60956</td>
#             </tr>
#             <tr>
#                         <th id="T_08000832_3b51_11e9_afbd_313de2e40688level0_row5" class="row_heading level0 row5" >Fully Implicit Simple, en ligne</th>
#                         <td id="T_08000832_3b51_11e9_afb

# %% [markdown]
# ### Classement par average reward normalisée (mean)

# %%
col = 'average_reward_normalized_mean' 
aggregat.sort_values(col, ascending=False)\
    .style.apply((lambda x: ['background: lightgreen' if x.name == col else '' for _ in x]))
# Out:
# <style  type="text/css" >
#     #T_08083ae8_3b51_11e9_afbd_313de2e40688row0_col5 {
#             background:  lightgreen;
#         }    #T_08083ae8_3b51_11e9_afbd_313de2e40688row1_col5 {
#             background:  lightgreen;
#         }    #T_08083ae8_3b51_11e9_afbd_313de2e40688row2_col5 {
#             background:  lightgreen;
#         }    #T_08083ae8_3b51_11e9_afbd_313de2e40688row3_col5 {
#             background:  lightgreen;
#         }    #T_08083ae8_3b51_11e9_afbd_313de2e40688row4_col5 {
#             background:  lightgreen;
#         }    #T_08083ae8_3b51_11e9_afbd_313de2e40688row5_col5 {
#             background:  lightgreen;
#         }    #T_08083ae8_3b51_11e9_afbd_313de2e40688row6_col5 {
#             background:  lightgreen;
#         }    #T_08083ae8_3b51_11e9_afbd_313de2e40688row7_col5 {
#             background:  lightgreen;
#         }    #T_08083ae8_3b51_11e9_afbd_313de2e40688row8_col5 {
#             background:  lightgreen;
#         }    #T_08083ae8_3b51_11e9_afbd_313de2e40688row9_col5 {
#             background:  lightgreen;
#         }    #T_08083ae8_3b51_11e9_afbd_313de2e40688row10_col5 {
#             background:  lightgreen;
#         }    #T_08083ae8_3b51_11e9_afbd_313de2e40688row11_col5 {
#             background:  lightgreen;
#         }    #T_08083ae8_3b51_11e9_afbd_313de2e40688row12_col5 {
#             background:  lightgreen;
#         }    #T_08083ae8_3b51_11e9_afbd_313de2e40688row13_col5 {
#             background:  lightgreen;
#         }    #T_08083ae8_3b51_11e9_afbd_313de2e40688row14_col5 {
#             background:  lightgreen;
#         }    #T_08083ae8_3b51_11e9_afbd_313de2e40688row15_col5 {
#             background:  lightgreen;
#         }    #T_08083ae8_3b51_11e9_afbd_313de2e40688row16_col5 {
#             background:  lightgreen;
#         }    #T_08083ae8_3b51_11e9_afbd_313de2e40688row17_col5 {
#             background:  lightgreen;
#         }    #T_08083ae8_3b51_11e9_afbd_313de2e40688row18_col5 {
#             background:  lightgreen;
#         }    #T_08083ae8_3b51_11e9_afbd_313de2e40688row19_col5 {
#             background:  lightgreen;
#         }    #T_08083ae8_3b51_11e9_afbd_313de2e40688row20_col5 {
#             background:  lightgreen;
#         }    #T_08083ae8_3b51_11e9_afbd_313de2e40688row21_col5 {
#             background:  lightgreen;
#         }    #T_08083ae8_3b51_11e9_afbd_313de2e40688row22_col5 {
#             background:  lightgreen;
#         }    #T_08083ae8_3b51_11e9_afbd_313de2e40688row23_col5 {
#             background:  lightgreen;
#         }</style><table id="T_08083ae8_3b51_11e9_afbd_313de2e40688" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >max_price</th>        <th class="col_heading level0 col1" >mean_price</th>        <th class="col_heading level0 col2" >average_reward</th>        <th class="col_heading level0 col3" >good_reco_ratio</th>        <th class="col_heading level0 col4" >average_reward_normalized_max</th>        <th class="col_heading level0 col5" >average_reward_normalized_mean</th>    </tr>    <tr>        <th class="index_name level0" >recommendation</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_08083ae8_3b51_11e9_afbd_313de2e40688level0_row0" class="row_heading level0 row0" >Null special, en ligne</th>
#                         <td id="T_08083ae8_3b51_11e9_afbd_313de2e40688row0_col0" class="data row0 col0" >963.908</td>
#                         <td id="T_08083ae8_3b51_11e9_afbd_313de2e40688row0_col1" class="data row0 col1" >70.0815</td>
#                         <td id="T_08083ae8_3b51_11e9_afbd_313de2e40688row0_col2" class="data row0 col2" >230.922</td>
#                         <td id="T_08083ae8_3b51_11e9_afbd_313de2e40688row0_col3" class="data row0 col3" >0.325</td>
#                         <td id="T_08083ae8_3b51_11e9_afbd_313de2e40688row0_col4" class="data row0 col4" >0.237329</td>
#                         <td id="T_08083ae8_3b51_11e9_afbd_313de2e40688row0_col5" class="data row0 col5" >3.30483</td>
#             </tr>
#             <tr>
#                         <th id="T_08083ae8_3b51_11e9_afbd_313de2e40688level0_row1" class="row_heading level0 row1" >Simple, en ligne (batch)</th>
#                         <td id="T_08083ae8_3b51_11e9_afbd_313de2e40688row1_col0" class="data row1 col0" >967.846</td>
#                         <td id="T_08083ae8_3b51_11e9_afbd_313de2e40688row1_col1" class="data row1 col1" >65.5067</td>
#                         <td id="T_08083ae8_3b51_11e9_afbd_313de2e40688row1_col2" class="data row1 col2" >180.599</td>
#                         <td id="T_08083ae8_3b51_11e9_afbd_313de2e40688row1_col3" class="data row1 col3" >0.288</td>
#                         <td id="T_08083ae8_3b51_11e9_afbd_313de2e40688row1_col4" class="data row1 col4" >0.186437</td>
#                         <td id="T_08083ae8_3b51_11e9_afbd_313de2e40688row1_col5" class="data row1 col5" >2.87125</td>
#             </tr>
#             <tr>
#                         <th id="T_08083ae8_3b51_11e9_afbd_313de2e40688level0_row2" class="row_heading level0 row2" >Fully Implicit Null, hors ligne</th>
#                         <td id="T_08083ae8_3b51_11e9_afbd_313de2e40688row2_col0" class="data row2 col0" >981.333</td>
#                         <td id="T_08083ae8_3b51_11e9_afbd_313de2e40688row2_col1" class="data row2 col1" >73.7996</td>
#                         <td id="T_08083ae8_3b51_11e9_afbd_313de2e40688row2_col2" class="data row2 col2" >210.346</td>
#                         <td id="T_08083ae8_3b51_11e9_afbd_313de2e40688row2_col3" class="data row2 col3" >0.328</td>
#                         <td id="T_08083ae8_3b51_11e9_afbd_313de2e40688row2_col4" class="data row2 col4" >0.214494</td>
#                         <td id="T_08083ae8_3b51_11e9_afbd_313de2e40688row2_col5" class="data row2 col5" >2.85239</td>
#             </tr>
#             <tr>
#                         <th id="T_08083ae8_3b51_11e9_afbd_313de2e40688level0_row3" class="row_heading level0 row3" >Fully Implicit Null binaire, en ligne</th>
#                         <td id="T_08083ae8_3b51_11e9_afbd_313de2e40688row3_col0" class="data row3 col0" >965.746</td>
#                         <td id="T_08083ae8_3b51_11e9_afbd_313de2e40688row3_col1" class="data row3 col1" >71.9374</td>
#                         <td id="T_08083ae8_3b51_11e9_afbd_313de2e40688row3_col2" class="data row3 col2" >197.025</td>
#                         <td id="T_08083ae8_3b51_11e9_afbd_313de2e40688row3_col3" class="data row3 col3" >0.335</td>
#                         <td id="T_08083ae8_3b51_11e9_afbd_313de2e40688row3_col4" class="data row3 col4" >0.204045</td>
#                         <td id="T_08083ae8_3b51_11e9_afbd_313de2e40688row3_col5" class="data row3 col5" >2.76287</td>
#             </tr>
#             <tr>
#                         <th id="T_08083ae8_3b51_11e9_afbd_313de2e40688level0_row4" class="row_heading level0 row4" >Null special, hors ligne</th>
#                         <td id="T_08083ae8_3b51_11e9_afbd_313de2e40688row4_col0" class="data row4 col0" >958.93</td>
#                         <td id="T_08083ae8_3b51_11e9_afbd_313de2e40688row4_col1" class="data row4 col1" >68.4424</td>
#                         <td id="T_08083ae8_3b51_11e9_afbd_313de2e40688row4_col2" class="data row4 col2" >182.678</td>
#                         <td id="T_08083ae8_3b51_11e9_afbd_313de2e40688row4_col3" class="data row4 col3" >0.331</td>
#                         <td id="T_08083ae8_3b51_11e9_afbd_313de2e40688row4_col4" class="data row4 col4" >0.191525</td>
#                         <td id="T_08083ae8_3b51_11e9_afbd_313de2e40688row4_col5" class="data row4 col5" >2.67524</td>
#             </tr>
#             <tr>
#                         <th id="T_08083ae8_3b51_11e9_afbd_313de2e40688level0_row5" class="row_heading level0 row5" >Fully Implicit Null binaire, en ligne (batch)</th>
#                         <td id="T_08083ae8_3b51_11e9_afbd_313de2e40688row5_col

# %% [markdown]
# ### Résumé (classé par average_reward)

# %%
cm = sns.light_palette("green", as_cmap=True)
col = ['average_reward_normalized_max', 'average_reward_normalized_mean']
aggregat.sort_values(col, ascending=False)\
    .style.background_gradient(cmap=cm).highlight_max(color='red')
# Out:
# <style  type="text/css" >
#     #T_08195d1e_3b51_11e9_afbd_313de2e40688row0_col0 {
#             background-color:  #5db35d;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row0_col1 {
#             background-color:  #85ca85;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row0_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             background-color:  red;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row0_col3 {
#             background-color:  #3da23d;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row0_col4 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             background-color:  red;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row0_col5 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             background-color:  red;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row1_col0 {
#             background-color:  #108910;
#             color:  #f1f1f1;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row1_col1 {
#             background-color:  #379e37;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row1_col2 {
#             background-color:  #289628;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row1_col3 {
#             background-color:  #319b31;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row1_col4 {
#             background-color:  #2b982b;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row1_col5 {
#             background-color:  #3ba13b;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row2_col0 {
#             background-color:  #8dce8d;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row2_col1 {
#             background-color:  #319b31;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row2_col2 {
#             background-color:  #41a441;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row2_col3 {
#             background-color:  #0b860b;
#             color:  #f1f1f1;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row2_col4 {
#             background-color:  #399f39;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row2_col5 {
#             background-color:  #54ae54;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row3_col0 {
#             background-color:  #55af55;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row3_col1 {
#             background-color:  #5eb45e;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row3_col2 {
#             background-color:  #42a442;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row3_col3 {
#             background-color:  #178c17;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row3_col4 {
#             background-color:  #40a340;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row3_col5 {
#             background-color:  #47a747;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row4_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             background-color:  red;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row4_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             background-color:  red;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row4_col2 {
#             background-color:  #42a442;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row4_col3 {
#             background-color:  #44a644;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row4_col4 {
#             background-color:  #46a746;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row4_col5 {
#             background-color:  #5bb25b;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row5_col0 {
#             background-color:  #9bd69b;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row5_col1 {
#             background-color:  #83c983;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row5_col2 {
#             background-color:  #56b056;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row5_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             background-color:  red;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row5_col4 {
#             background-color:  #51ad51;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row5_col5 {
#             background-color:  #55af55;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row6_col0 {
#             background-color:  #4fac4f;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row6_col1 {
#             background-color:  #4aa94a;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row6_col2 {
#             background-color:  #53ae53;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row6_col3 {
#             background-color:  #41a441;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row6_col4 {
#             background-color:  #53ae53;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row6_col5 {
#             background-color:  #5eb45e;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row7_col0 {
#             background-color:  #72bf72;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row7_col1 {
#             background-color:  #a8dda8;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row7_col2 {
#             background-color:  #5eb45e;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row7_col3 {
#             background-color:  #269526;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row7_col4 {
#             background-color:  #58b158;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row7_col5 {
#             background-color:  #53ae53;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row8_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row8_col1 {
#             background-color:  #a3daa3;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row8_col2 {
#             background-color:  #6bbb6b;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row8_col3 {
#             background-color:  #7ec67e;
#             color:  #000000;
#             : ;
#         }    #T_08195d1e_3b51_11e9_afbd_313de2e40688row8_col4 {
#             background-color:  #5db35d;

# %% [markdown]
# La recommendation prenant en charge les nulls semble meilleure. <br>
#   1) Null secial en ligne (batch) <br>
#   2) Fully Implicit Null special, en ligne (batch) <br>
#   3) Null, hors ligne <br>
